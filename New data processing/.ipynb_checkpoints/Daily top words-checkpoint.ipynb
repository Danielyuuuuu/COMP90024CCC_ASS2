# %%
from database_cloudant import CloudantDB
from cloudant.design_document import DesignDocument
from cloudant.view import View
import sys



#db1 = CloudantDB("tweets_keywords")    # tweets in the specified location with keywords 
#db2 = CloudantDB("tweets_no_keywords") # tweets in the sepcified locations without keyowrds
#db3 = CloudantDB("tweets_raw")         # raw tweet data in the specified locations
db4=CloddantDB("")
#print(len(db1.get_data()))
#print(db2.get_data(n=10000))
#print(len(db3.get_data(n=10)))



    
def dataofday(date):    
    # get all data from a specific day
    db1 = CloudantDB("tweets_keywords")    # tweets in the specified location with keywords 
    db2 = CloudantDB("tweets_no_keywords") # tweets in the sepcified locations without keyowrds
    n = 100  # number of tweets need to retrieve
    ddoc = DesignDocument(db2.curDB, '_design/ddoc001')
    ddoc.fetch()
    view = View(ddoc,"view_time")
    data = []
    for row in view(group=False,limit=n,reduce=False,key=date,include_docs=True)["rows"]:
        data.append(row)
    
    db1.close()
    db2.close()
    return data

    
    

    
#db3.close()
def city_daily_popular_10words(tweetlist):
    city=[]
    for k in tweetlist:
        if k["zone"] not in city:
            city.append(k["zone"])
    alltext={}
    for c in city:
        alltext[c]=[]
    for k in tweetlist:
        for c in city:
            if k["zone"] in c:
                alltext[c].append(k["text"])
    popdict={}             
    for c in city:
        popdict[c]=top_words(alltext[c])
    return popdict


if __name__ == "main":
    ipaddress=sys.argv[-1]

    date = "2021-01-01"
    data=dataofday(date)

    citytopwords=city_daily_popular_10words(data)
    print(citytopwords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-38e0c7547437> in <module>
#       9 #db2 = CloudantDB("tweets_no_keywords") # tweets in the sepcified locations without keyowrds
#      10 #db3 = CloudantDB("tweets_raw")         # raw tweet data in the specified locations
# ---> 11 db4=CloddantDB("")
#      12 #print(len(db1.get_data()))
#      13 #print(db2.get_data(n=10000))
#
# NameError: name 'CloddantDB' is not defined

# %%
def get_data_summary(db="covid",viewType="month",startkey="2020-10",mode = "mean"):
    if(db=="covid"):
        db = CloudantDB('tweets_covid')
    elif(db=="vaccine"):
        db= CloudantDB("tweets_vaccine")
    elif(db=="no_keywords"):
        db=CloudantDB('tweets_no_keywords')
    else:
        print("db parameter must in [covid,vaccine,no_keywords]")
        return {}
    ddoc = DesignDocument(db.curDB,'_design/ddoc001')
    ddoc.fetch()
    if(viewType=="month"):
        view = View(ddoc, 'view_month')
    elif(viewType=="zone"):
        view = View(ddoc,"view_zone")
    elif(viewType=="zone month"):
        view=View(ddoc, 'view_zone_month')
    else:
        view = View(ddoc, 'view_time')
    result = {}
    for row in view(limit=1000,reduce=True,group=True,startkey=startkey)['rows']:
        if(mode=="mean"):
            result[row['key']] = round(row['value']['sum']/row['value']['count'],6)
        elif(mode=="count"):
            result[row['key']] = row['value']['count']
    return result

def get_data(n=100,db="covid",viewType="day",startkey="2021-05-01"):
    if(db=="covid"):
        db = CloudantDB('tweets_covid')
    elif(db=="vaccine"):
        db= CloudantDB("tweets_vaccine")
    elif(db=="no_keywords"):
        db=CloudantDB('tweets_no_keywords')
    else:
        print("db parameter must in [covid,vaccine,no_keywords]")
        return []
    ddoc = DesignDocument(db.curDB,'_design/ddoc001')
    ddoc.fetch()
    if(viewType=="zone"):
        view = View(ddoc,"view_zone")
    elif(viewType=="day"):
        view = View(ddoc, 'view_time')
    else:
        return "Does not support viewType"+viewType
    result = []
    for row in view(limit=n,reduce=False,group=False,startkey=startkey,include_docs=True)['rows']:
        result.append(row)
    return result

# %%
get_data_summary(db="no_keywords",viewType="zone")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_no_keywords
# {'Adelaide': 0.693848,
#  'Ballarat': 0.715091,
#  'Brisbane': 0.710385,
#  'Bunbury': 0.80026,
#  'Canberra': 0.690317,
#  'Geelong': 0.678222,
#  'Hobart': 0.690671,
#  'Melbourne': 0.704503,
#  'Newcastle': 0.75033,
#  'Perth': 0.700816,
#  'Sydney': 0.723348}

# %%
monthsentidict=get_data_summary(viewType="zone")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_covid

# %%
get_data_summary(viewType="zone month")
get_data_summary(db="vaccine",viewType="zone month")
get_data_summary(db="vaccine",viewType="zone")
get_data_summary(viewType="zone")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_covid
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_vaccine
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_vaccine
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_covid
# {'Adelaide': 0.596067,
#  'Ballarat': 0.737719,
#  'Brisbane': 0.567257,
#  'Bunbury': 0.688183,
#  'Canberra': 0.518975,
#  'Geelong': 0.611571,
#  'Hobart': 0.48139,
#  'Melbourne': 0.589867,
#  'Newcastle': 0.714606,
#  'Perth': 0.56422,
#  'Sydney': 0.542216}

# %%
monthsentidict
# Out:
# {'Adelaide': 0.596067,
#  'Ballarat': 0.737719,
#  'Brisbane': 0.567257,
#  'Bunbury': 0.688183,
#  'Canberra': 0.518975,
#  'Geelong': 0.611571,
#  'Hobart': 0.48139,
#  'Melbourne': 0.589867,
#  'Newcastle': 0.714606,
#  'Perth': 0.56422,
#  'Sydney': 0.542216}

# %%
get_data(db="no_keywords",viewType="month")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_no_keywords
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-66-55c6b0b06365> in <module>
# ----> 1 get_data(db="no_keywords",viewType="month")
#
# <ipython-input-65-a359f46f0548> in get_data(n, db, viewType, startkey)
#      48         return "Does not support viewType"+viewType
#      49     result = []
# ---> 50     for row in view(limit=n,reduce=False,group=False,startkey=startkey,include_docs=True)['rows']:
#      51         result.append(row)
#      52     return result
#
# ~\anaconda3\lib\site-packages\cloudant\view.py in __call__(self, **kwargs)
#     234         :returns: View result data in JSON format
#     235         """
# --> 236         resp = get_docs(self._r_session,
#     237                         self.url,
#     238                         self.design_doc.encoder,
#
# ~\anaconda3\lib\site-packages\cloudant\_common_util.py in get_docs(r_session, url, encoder, headers, **params)
#     260     else:
#     261         resp = r_session.get(url, headers=headers, params=f_params)
# --> 262     resp.raise_for_status()
#     263     return resp
#     264
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 404 Client Error: Object Not Found not_found missing_named_view for url: http://172.26.131.97:5984/tweets_no_keywords/_design/ddoc001/_view/view_month?limit=100&reduce=false&group=false&startkey=%222021-05%22&include_docs=true

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords


def top_words(textlist,top=10):
    stop_words = stopwords.words('english')
    wordfreqdict={}
    popular=[]
    tokenizer=TweetTokenizer()
    for t in textlist:
        token = tokenizer.tokenize(t)
        for w in token:
            if w not in wordfreqdict.keys():
                wordfreqdict[w]=1
            else:
                wordfreqdict[w]+=1
    sorted_values = sorted(wordfreqdict.values(), reverse=True) # Sort the values
    count=0
    for i in sorted_values:
        for k in wordfreqdict.keys():
            if wordfreqdict[k] == i:
                if len(k)>=5 and k not in popular and k not in stop_words:
                    
                    popular.append(k)
                    count+=1
                if count > top:
                    break
             
    popdict={}
    for p in popular:
        popdict[p]=wordfreqdict[p]
    return popdict
def city_daily_popular_10words():

    city=[]
    tweetlist=get_data(n=3000,db="no_keywords",viewType="day")
    for k in  tweetlist:
        if k["doc"]["place"]["name"] not in city:
            city.append(k["doc"]["place"]["name"])
    alltext={}
    for c in city:
        alltext[c]=[]
    for k in tweetlist:
        for c in city:
            if k["doc"]["place"]["name"] in c:
                alltext[c].append(k["doc"]["text"])
    popdict={}             
    for c in city:
        popdict[c]=top_words(alltext[c])
    return popdict

# %%
city_daily_popular_10words()
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_no_keywords
# {'Sydney': {'posted': 108,
#   'photo': 103,
#   'Australia': 80,
#   'Sydney': 76,
#   'today': 25,
#   'first': 18,
#   'video': 14,
#   'South': 14,
#   'Monday': 13,
#   'morning': 12,
#   'really': 12,
#   'people': 9,
#   'Saturday': 8,
#   'Bondi': 7,
#   'Beach': 5,
#   'Point': 4,
#   'https://t.co/wL81mg2GsI': 1},
#  'Adelaide': {'Adelaide': 12,
#   'Australian': 8,
#   "Women's": 8,
#   'Baseball': 8,
#   'Showcase': 8,
#   'today': 8,
#   '@baseballcomau': 7,
#   'Australia': 6,
#   'South': 5,
#   'posted': 5,
#   'photo': 5,
#   '#morninginspiration': 4,
#   'Professor': 1},
#  'Melbourne': {'posted': 72,
#   'photo': 71,
#   'Melbourne': 47,
#   'Victoria': 44,
#   'Australia': 41,
#   'today': 36,
#   'Patient': 18,
#   'going': 17,
#   'getting': 16,
#   'Drinking': 15,
#   'would': 14,
#   'please': 13,
#   'school': 6,
#   'community': 5,
#   'playing': 3,
#   'dedicated': 2,
#   'https://t.co/viNEwwhlNc': 1},
#  'Newcastle': {'Newcastle': 7,
#   'posted': 6,
#   'photo': 6,
#   'great': 4,
#   'South': 4,
#   'Wales': 4,
#   '#IMM21': 2,
#   '#MultipleSclerosis': 2,
#   'joining': 2,
#   'hopefully': 2,
#   '#Love30': 2},
#  'Brisbane': {'posted': 24,
#   'photo': 23,
#   'Brisbane': 17,
#   'Australia': 12,
#   'Queensland': 8,
#   'today': 7,
#   'Stuff': 5,
#   'IT-nlee': 5,
#   'better': 5,
#   'years': 5,
#   'first': 5,
#   'Sunday': 3,
#   'Breakfast': 1},
#  'Canberra': {'posted': 8,
#   '@CBRLangtrees': 6,
#   'understand': 6,
#   'photo': 6,
#   'great': 5,
#   'Burley': 5,
#   'Strength': 5,
#   'people': 5,
#   'today': 4,
#   'Australia': 4,
#   '@AaronLangtrees': 4,
#   'PLACE': 1},
#  'Perth Children’s Hospital': {'Aswath': 1,
#   'Prasitha': 1,
#   'parents': 1,
#   'Aishwarya': 1,
#   'hunger': 1,
#   'strike': 1,
#   'outside': 1,
#   'Perth': 1,
#   'Children': 1,
#   'https://t.co/4oFUbhB5Of': 1},
#  'Perth (WA)': {'posted': 19,
#   'Perth': 18,
#   '️0893252011': 18,
#   'photo': 17,
#   'Australia': 17,
#   '@11AberdeenStreet': 17,
#   'Western': 15,
#   'today': 8,
#   'Sandy': 8,
#   'still': 7,
#   'people': 6,
#   'Happy': 4,
#   '#foreverfreo': 3,
#   'really': 2},
#  'Ballarat': {'Abstract': 7,
#   'Painting': 4,
#   'Roses': 4,
#   '#abstractart': 3,
#   '#recycle': 3,
#   'Centennial': 2,
#   'Drinking': 2,
#   'Portrait': 2,
#   '#artsale': 2,
#   '#artforsale': 2,
#   'Fabric': 2},
#  'Cronulla': {'#Shire': 1,
#   '#RelayforLife': 1,
#   'swing': 1,
#   '#Cronulla': 1,
#   'https://t.co/Rz1FOcKXUP': 1},
#  'Hobart': {'Transmission': 4,
#   'getting': 2,
#   '#photoOfTheDay': 2,
#   'iPhone': 2,
#   'TwitterBot': 2,
#   'GitHub': 2,
#   'https://t.co/HrXewkdeqn': 2,
#   '#rekognition': 2,
#   'worse': 2,
#   'Hobart': 2,
#   'Tasmania': 2,
#   '#TheWarofLongSleep': 1},
#  'Brisbane Convention & Exhibition Centre': {'posted': 24,
#   'photo': 23,
#   'Brisbane': 18,
#   'Australia': 13,
#   'Queensland': 8,
#   'today': 7,
#   'Stuff': 5,
#   'IT-nlee': 5,
#   'better': 5,
#   'years': 5,
#   'first': 5,
#   'Sunday': 3,
#   'Breakfast': 1},
#  'Geelong': {'Geelong': 3,
#   'Sunday': 2,
#   '#Geelong': 2,
#   'Frank': 2,
#   'Costa': 2,
#   'watch': 2,
#   'seriously': 2,
#   '#MVCvCCM': 2,
#   'Fabulous': 1,
#   'Congratulations': 1,
#   'Stephanie': 1},
#  'Narre Warren': {'@NarreWarrenFNC': 8,
#   'Doveton': 8,
#   '@AFL_OE': 8,
#   '#afloeprem': 8,
#   'Reserves': 4,
#   'SENIORS': 4,
#   'FINAL': 2,
#   'SCORE': 2,
#   'Round': 1,
#   'Development': 1,
#   'ground': 1},
#  'Glebe': {'vegetarians': 1, 'goanna': 1, 'https://t.co/g4a4jc0i5z': 1},
#  'South Yarra': {'keeps': 1, 'going': 1, 'https://t.co/ifdqNMCMcX': 1},
#  'Sydney Cricket Ground': {'posted': 108,
#   'photo': 103,
#   'Australia': 80,
#   'Sydney': 76,
#   'today': 25,
#   'first': 18,
#   'video': 14,
#   'South': 14,
#   'Monday': 13,
#   'morning': 12,
#   'really': 12,
#   'people': 9,
#   'Saturday': 8,
#   'Bondi': 7,
#   'Beach': 5,
#   'Point': 4,
#   'https://t.co/wL81mg2GsI': 1},
#  'Albion': {'Happy': 1,
#   'Saturday': 1,
#   'packed': 1,
#   'Mothers': 1,
#   'Community': 1,
#   'Market': 1,
#   'Fabulous': 1,
#   'stalls': 1,
#   'showcasing': 1,
#   'https://t.co/YCuHlLaZ9x': 1},
#  'Gymea': {'#ChristosAnesti': 1,
#   'Happy': 1,
#   '#Easter': 1,
#   '#Orthodox': 1,
#   'Christians': 1,
#   'Several': 1,
#   'thousand': 1,
#   'celebrated': 1,
#   'midnight': 1,
#   'Stylianos': 1,
#   'https://t.co/rT8DUtHvuS': 1},
#  'Manly': {'Testing': 1,
#   'Manly': 1,
#   'Adelaide': 1,
#   '@_southstart': 1,
#   'Excited': 1,
#   'https://t.co/Bst23JIxsD': 1,
#   'Power': 1,
#   '#WeAreCisco': 1,
#   'spirit': 1,
#   'grateful': 1,
#   'catch': 1},
#  'Adelaide Airport (ADL)': {'Adelaide': 13,
#   'Australian': 8,
#   "Women's": 8,
#   'Baseball': 8,
#   'Showcase': 8,
#   'today': 8,
#   '@baseballcomau': 7,
#   'Australia': 6,
#   'South': 5,
#   'posted': 5,
#   'photo': 5,
#   '#morninginspiration': 4,
#   'Professor': 1},
#  'St Albans': {'Today': 1,
#   'joined': 1,
#   'members': 1,
#   'Chintapurni': 1,
#   'Hindu': 1,
#   'Temple': 1,
#   'prayer': 1,
#   'reflection': 1,
#   'India': 1,
#   'https://t.co/NKRyZi70Tq': 1,
#   'Congratulations': 1},
#  'Emu Plains': {'think': 1,
#   'mountains': 1,
#   'decades': 1,
#   'https://t.co/FsBQfEDrVu': 1},
#  'Doncaster': {'@LEGOMastersAU': 6,
#   'Thanks': 3,
#   '@MaddyTyers': 3,
#   '@jimmyjameseaton': 3,
#   '@Channel9': 3,
#   'meeting': 3,
#   'coming': 3,
#   'https://t.co/XFTVQVEpao': 1,
#   'https://t.co/iGoMI0CO35': 1,
#   'https://t.co/J5P90dMqrW': 1},
#  'Grovedale': {'Looking': 1,
#   'towards': 1,
#   'Armstrong': 1,
#   'Creek': 1,
#   'Mount': 1,
#   'Duneed': 1,
#   'Resulted': 1,
#   'nothing': 1,
#   'https://t.co/hrHAT5nVQ3': 1},
#  'Box Hill': {'Engaging': 1,
#   'Sunday': 1,
#   'afternoon': 1,
#   'presentation': 1,
#   'Climate': 1,
#   'Professor': 1,
#   'Flannery': 1,
#   'Nicki': 1,
#   'Hutley': 1,
#   'https://t.co/ONJR3mQ5mJ': 1},
#  'Brisbane City': {'posted': 24,
#   'photo': 23,
#   'Brisbane': 17,
#   'Australia': 12,
#   'Queensland': 8,
#   'today': 7,
#   'Stuff': 5,
#   'IT-nlee': 5,
#   'better': 5,
#   'years': 5,
#   'first': 5,
#   'Sunday': 3,
#   'Breakfast': 1},
#  'Devon Meadows': {'MELBOURNE': 1,
#   'Crystals': 1,
#   'dinosaurs': 1,
#   'sunny': 1,
#   'Sunday': 1,
#   'Crystal': 1,
#   'World': 1,
#   'hidden': 1,
#   'https://t.co/CwsRNZucfK': 1},
#  'Kings Park Perth': {'International': 2,
#   'Firefighters': 2,
#   'honour': 1,
#   'commemorate': 1,
#   'fallen': 1,
#   'firefighters': 1,
#   'Memorial': 1,
#   'Service': 1,
#   'https://t.co/uLq5EBHkDD': 1,
#   'Commemorating': 1,
#   'ultimate': 1},
#  'Belmont': {'brief': 1,
#   'thunderstorm': 1,
#   'tonight': 1,
#   'actually': 1,
#   'quite': 1,
#   'quick': 1,
#   'https://t.co/ei3eG4H7xq': 1},
#  'Waterloo': {'Bizarre': 1,
#   'could': 1,
#   'piece': 1,
#   'paper': 1,
#   'times': 1,
#   'thickness': 1,
#   'would': 1,
#   'exceed': 1,
#   'distance': 1},
#  'Carlisle': {'times': 1, 'begin': 1, 'https://t.co/BZagCCWeN5': 1},
#  'Frankston': {'#optimism': 2,
#   'essence': 1,
#   'persist': 1,
#   'adversity': 1,
#   'better': 1,
#   'offers': 1,
#   'https://t.co/vI14fVZw81': 1,
#   'Image': 1,
#   '#wonder_doodles': 1,
#   'beliefs': 1,
#   'inform': 1},
#  'Sydney Harbour Bridge': {'posted': 108,
#   'photo': 103,
#   'Australia': 80,
#   'Sydney': 76,
#   'today': 25,
#   'first': 18,
#   'video': 14,
#   'South': 14,
#   'morning': 13,
#   'Monday': 13,
#   'really': 12,
#   'people': 9,
#   'Saturday': 8,
#   'Bondi': 7,
#   'Beach': 5,
#   'Point': 4,
#   'https://t.co/wL81mg2GsI': 1},
#  'Darling Point': {'Sydney': 1,
#   'smoke': 1,
#   'bridge': 1,
#   'https://t.co/XPbhUi2Iz9': 1},
#  'Mount Coot-Tha': {'Coot-tha': 1,
#   'eagle': 1,
#   'Brisbane': 1,
#   '#goodmorningpost': 1,
#   '#goodvibesonly': 1,
#   '#postpamore': 1,
#   '#trebligsjourney2021': 1,
#   'https://t.co/gyZagHagra': 1},
#  'Adelaide Entertainment Centre': {'Adelaide': 12,
#   'Australian': 8,
#   "Women's": 8,
#   'Baseball': 8,
#   'Showcase': 8,
#   'today': 8,
#   '@baseballcomau': 7,
#   'Australia': 6,
#   'South': 5,
#   'posted': 5,
#   'photo': 5,
#   '#morninginspiration': 4,
#   'Professor': 1},
#  'Melville': {'Mandalorian': 1,
#   'series': 1,
#   'Picture': 1,
#   'shows': 1,
#   'large': 1,
#   'purse': 1,
#   'black': 1,
#   'cotton': 1,
#   'https://t.co/zgF8bogdn4': 1},
#  'Paddington': {'Harvest': 1, 'https://t.co/0xZRc6YTZq': 1},
#  'Chermside': {'https://t.co/m6PIx7k6ap': 1},
#  'Sydney Jewish Museum': {'posted': 108,
#   'photo': 103,
#   'Australia': 80,
#   'Sydney': 76,
#   'today': 25,
#   'first': 18,
#   'video': 14,
#   'South': 14,
#   'Monday': 13,
#   'morning': 12,
#   'really': 12,
#   'Saturday': 8,
#   'Bondi': 7,
#   'Beach': 5,
#   'Point': 4,
#   'https://t.co/wL81mg2GsI': 1},
#  'South Granville': {'tweet': 2,
#   'https://t.co/epvOCR33HW': 1,
#   'matcha': 1,
#   'tastes': 1,
#   'funny': 1,
#   'Kinda': 1,
#   'preachy': 1,
#   'tweets': 1,
#   'dunno': 1,
#   'beverages': 1,
#   'According': 1},
#  'Bowen Hills': {'https://t.co/zoej83LJV4': 1},
#  'Erskineville': {'Bunny': 2,
#   'Rusty': 2,
#   'Monday': 1,
#   'Child': 1,
#   'https://t.co/CsA3tXkCFd': 1,
#   'https://t.co/MDFEGTEY9m': 1,
#   'https://t.co/Yh1AtxCL8O': 1,
#   'Rustier': 1,
#   'https://t.co/VFfzkpDAF4': 1,
#   'https://t.co/p2hOwBuyhB': 1,
#   'Lunch': 1},
#  'Port Melbourne': {'posted': 72,
#   'photo': 71,
#   'Melbourne': 47,
#   'Victoria': 44,
#   'Australia': 41,
#   'today': 36,
#   'Patient': 18,
#   'going': 17,
#   'getting': 16,
#   'Drinking': 15,
#   'would': 14,
#   'please': 13,
#   'school': 6,
#   'community': 5,
#   'playing': 3,
#   'dedicated': 2,
#   'https://t.co/viNEwwhlNc': 1},
#  'Fortitude Valley': {'Welcome': 1,
#   'honour': 1,
#   'follow': 1,
#   'Enjoy': 1,
#   '#club29': 1,
#   '#folsomdownunder': 1,
#   '#gaybris': 1,
#   '#bros4brosnolabels': 1,
#   'https://t.co/WjCl193N9u': 1},
#  'Redfern': {'Blood': 2,
#   'Report': 1,
#   'Apple': 1,
#   'Watch': 1,
#   'Could': 1,
#   'Sugar': 1,
#   'Pressure': 1,
#   'Measurement': 1,
#   'Abilities': 1,
#   'https://t.co/hOAau0BqBn': 1,
#   'https://t.co/0z4Y65oXot': 1},
#  'Parramatta': {'Secondary': 1,
#   'Schools': 1,
#   'Riverside': 1,
#   'Theatre': 1,
#   'excited': 1,
#   'junior': 1,
#   'students': 1,
#   'first': 1,
#   'school': 1,
#   'excursion': 1,
#   'https://t.co/wYeVl1oivY': 1},
#  'Melbourne Airport': {'posted': 72,
#   'photo': 71,
#   'Melbourne': 47,
#   'Victoria': 44,
#   'Australia': 41,
#   'today': 36,
#   'Patient': 18,
#   'going': 17,
#   'getting': 16,
#   'Drinking': 15,
#   'would': 14,
#   'please': 13,
#   'school': 6,
#   'community': 5,
#   'playing': 3,
#   'dedicated': 2,
#   'https://t.co/viNEwwhlNc': 1},
#  'Kings Park': {'Commemorating': 1,
#   'International': 1,
#   'Firefighters': 1,
#   'ultimate': 1,
#   'sacrifice': 1,
#   'https://t.co/JWhGpkfn35': 1},
#  'Redcliffe': {'Mason': 1,
#   'morning': 1,
#   'beautiful': 1,
#   'Redcliffe': 1,
#   'Lagoon': 1,
#   'https://t.co/8wadAlHUwC': 1},
#  'The University of Adelaide': {'Adelaide': 12,
#   'Australian': 8,
#   "Women's": 8,
#   'Baseball': 8,
#   'Showcase': 8,
#   'today': 8,
#   '@baseballcomau': 7,
#   'Australia': 6,
#   'South': 5,
#   'posted': 5,
#   'photo': 5,
#   '#morninginspiration': 4,
#   'Professor': 1},
#  'Morphett Vale': {'Beautiful': 1, 'Autumn': 1, 'https://t.co/YH37mc5uo3': 1}}

# %%
get_data(db="no_keywords",viewType="day")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_no_keywords
# []
