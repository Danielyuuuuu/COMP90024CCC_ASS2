# %%
from database_cloudant import CloudantDB
from cloudant.design_document import DesignDocument
from cloudant.view import View
import sys



#db1 = CloudantDB("tweets_keywords")    # tweets in the specified location with keywords 
#db2 = CloudantDB("tweets_no_keywords") # tweets in the sepcified locations without keyowrds
#db3 = CloudantDB("tweets_raw")         # raw tweet data in the specified locations
db4=CloddantDB("")
#print(len(db1.get_data()))
#print(db2.get_data(n=10000))
#print(len(db3.get_data(n=10)))



    
def dataofday(date):    
    # get all data from a specific day
    db1 = CloudantDB("tweets_keywords")    # tweets in the specified location with keywords 
    db2 = CloudantDB("tweets_no_keywords") # tweets in the sepcified locations without keyowrds
    n = 100  # number of tweets need to retrieve
    ddoc = DesignDocument(db2.curDB, '_design/ddoc001')
    ddoc.fetch()
    view = View(ddoc,"view_time")
    data = []
    for row in view(group=False,limit=n,reduce=False,key=date,include_docs=True)["rows"]:
        data.append(row)
    
    db1.close()
    db2.close()
    return data

    
    

    
#db3.close()
def city_daily_popular_10words(tweetlist):
    city=[]
    for k in tweetlist:
        if k["zone"] not in city:
            city.append(k["zone"])
    alltext={}
    for c in city:
        alltext[c]=[]
    for k in tweetlist:
        for c in city:
            if k["zone"] in c:
                alltext[c].append(k["text"])
    popdict={}             
    for c in city:
        popdict[c]=top_words(alltext[c])
    return popdict


if __name__ == "main":
    ipaddress=sys.argv[-1]

    date = "2021-01-01"
    data=dataofday(date)

    citytopwords=city_daily_popular_10words(data)
    print(citytopwords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-38e0c7547437> in <module>
#       9 #db2 = CloudantDB("tweets_no_keywords") # tweets in the sepcified locations without keyowrds
#      10 #db3 = CloudantDB("tweets_raw")         # raw tweet data in the specified locations
# ---> 11 db4=CloddantDB("")
#      12 #print(len(db1.get_data()))
#      13 #print(db2.get_data(n=10000))
#
# NameError: name 'CloddantDB' is not defined

# %%
def get_data_summary(db="covid",viewType="month",startkey="2020-10",mode = "mean"):
    if(db=="covid"):
        db = CloudantDB('tweets_covid')
    elif(db=="vaccine"):
        db= CloudantDB("tweets_vaccine")
    elif(db=="no_keywords"):
        db=CloudantDB('tweets_no_keywords')
    else:
        print("db parameter must in [covid,vaccine,no_keywords]")
        return {}
    ddoc = DesignDocument(db.curDB,'_design/ddoc001')
    ddoc.fetch()
    if(viewType=="month"):
        view = View(ddoc, 'view_month')
    elif(viewType=="zone"):
        view = View(ddoc,"view_zone")
    elif(viewType=="zone month"):
        view=View(ddoc, 'view_zone_month')
    else:
        view = View(ddoc, 'view_time')
    result = {}
    for row in view(limit=100,reduce=True,group=True,startkey=startkey)['rows']:
        if(mode=="mean"):
            result[row['key']] = round(row['value']['sum']/row['value']['count'],6)
        elif(mode=="count"):
            result[row['key']] = row['value']['count']
    return result

def get_data(n=100,db="covid",viewType="day",startkey="2021-05-01"):
    if(db=="covid"):
        db = CloudantDB('tweets_covid')
    elif(db=="vaccine"):
        db= CloudantDB("tweets_vaccine")
    elif(db=="no_keywords"):
        db=CloudantDB('tweets_no_keywords')
    else:
        print("db parameter must in [covid,vaccine,no_keywords]")
        return []
    ddoc = DesignDocument(db.curDB,'_design/ddoc001')
    ddoc.fetch()
    if(viewType=="zone"):
        view = View(ddoc,"view_zone")
    elif(viewType=="day"):
        view = View(ddoc, 'view_time')
    else:
        return "Does not support viewType"+viewType
    result = []
    for row in view(limit=n,reduce=False,group=False,startkey=startkey,include_docs=True)['rows']:
        result.append(row)
    return result

# %%
monthsentidict=get_data_summary(viewType="zone")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_covid

# %%
get_data_summary(viewType="zone month")
get_data_summary(db="vaccine",viewType="zone month")
get_data_summary(db="vaccine",viewType="zone")
get_data_summary(viewType="zone")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# OSError: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000022A9954F280>: Failed to establish a new connection: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='172.26.131.97', port=5984): Max retries exceeded with url: /_session (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000022A9954F280>: Failed to establish a new connection: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-36-e732030c02da> in <module>
# ----> 1 get_data_summary(viewType="zone month")
#       2 get_data_summary(db="vaccine",viewType="zone month")
#       3 get_data_summary(db="vaccine",viewType="zone")
#       4 get_data_summary(viewType="zone")
#
# <ipython-input-8-0c1e2a795c41> in get_data_summary(db, viewType, startkey, mode)
#       1 def get_data_summary(db="covid",viewType="month",startkey="2020-10",mode = "mean"):
#       2     if(db=="covid"):
# ----> 3         db = CloudantDB('tweets_covid')
#       4     elif(db=="vaccine"):
#       5         db= CloudantDB("tweets_vaccine")
#
# ~\OneDrive\文档\GitHub\COMP90024CCC_ASS2\New data processing\database_cloudant.py in __init__(self, db_name, username, password, url)
#      12 class CloudantDB():
#      13     def __init__(self,db_name,username = USERNAME,password=PASSWORD,url = URL):
# ---> 14         self.client = CouchDB(username, password, url=url, connect=True)
#      15         self.session = self.client.session()
#      16         self.curDB = None
#
# ~\anaconda3\lib\site-packages\cloudant\client.py in __init__(self, user, auth_token, admin_party, **kwargs)
#     120         connect_to_couch = kwargs.get('connect', False)
#     121         if connect_to_couch and self._DATABASE_CLASS == CouchDatabase:
# --> 122             self.connect()
#     123
#     124     @property
#
# ~\anaconda3\lib\site-packages\cloudant\client.py in connect(self)
#     188             self.r_session.headers.update(self._client_user_header)
#     189
# --> 190         self.session_login()
#     191
#     192         # Utilize an event hook to append to the response message
#
# ~\anaconda3\lib\site-packages\cloudant\client.py in session_login(self, user, passwd)
#     229         :param str auth_token: Authentication token used to connect to server.
#     230         """
# --> 231         self.change_credentials(user=user, auth_token=passwd)
#     232
#     233     def change_credentials(self, user=None, auth_token=None):
#
# ~\anaconda3\lib\site-packages\cloudant\client.py in change_credentials(self, user, auth_token)
#     239         """
#     240         self.r_session.set_credentials(user, auth_token)
# --> 241         self.r_session.login()
#     242
#     243     def session_logout(self):
#
# ~\anaconda3\lib\site-packages\cloudant\_client_session.py in login(self)
#     148         Perform cookie based user login.
#     149         """
# --> 150         resp = super(CookieSession, self).request(
#     151             'POST',
#     152             self._session_url,
#
# ~\anaconda3\lib\site-packages\cloudant\_client_session.py in request(self, method, url, **kwargs)
#      63         Overrides ``requests.Session.request`` to set the timeout.
#      64         """
# ---> 65         resp = super(ClientSession, self).request(
#      66             method, url, timeout=self._timeout, **kwargs)
#      67
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='172.26.131.97', port=5984): Max retries exceeded with url: /_session (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000022A9954F280>: Failed to establish a new connection: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。'))

# %%
monthsentidict
# Out:
# {'Adelaide': 0.596067,
#  'Ballarat': 0.737719,
#  'Brisbane': 0.567257,
#  'Bunbury': 0.688183,
#  'Canberra': 0.518975,
#  'Geelong': 0.611571,
#  'Hobart': 0.48139,
#  'Melbourne': 0.589867,
#  'Newcastle': 0.714606,
#  'Perth': 0.56422,
#  'Sydney': 0.542216}

# %%
get_data(db="vaccine",viewType="zone")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_vaccine
# [{'id': '1244942062601924610',
#   'key': 'Adelaide',
#   'value': 0.045734257,
#   'doc': {'_id': '1244942062601924610',
#    '_rev': '1-eeacfb0a05e942dd760b41d4a9b28d5b',
#    'id': 1244942062601924610,
#    'user_id': 1122798742942339072,
#    'created_at': '2020-03-31 10:58:12',
#    'text': 'Had a flu jab today and now feel like death warmed up. Whyyyyyyyyy 😭🤮',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.045734257',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'jab'}},
#  {'id': '1363807123252023299',
#   'key': 'Adelaide',
#   'value': 0.89913225,
#   'doc': {'_id': '1363807123252023299',
#    '_rev': '1-909bb4182e061452cd7d3a93b86cbda0',
#    'id': 1363807123252023299,
#    'user_id': 3098520260,
#    'created_at': '2021-02-22 11:05:31',
#    'text': 'South Australia begins vaccine rollout with Premier Steven Marshall first to receive the jab… https://t.co/e5DKWAxzVb',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.89913225',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine jab'}},
#  {'id': '1369864864970153984',
#   'key': 'Adelaide',
#   'value': 0.9888517,
#   'doc': {'_id': '1369864864970153984',
#    '_rev': '1-08ec351caa687535da95e4d1949b66d4',
#    'id': 1369864864970153984,
#    'user_id': 749131123200892928,
#    'created_at': '2021-03-11 04:16:49',
#    'text': 'First vaccine jab done! Thanks to the amazing staff at FMC who made it a really informed, easy experience. Looking… https://t.co/bK9vbQCZew',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9888517',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine jab'}},
#  {'id': '1372654897280077825',
#   'key': 'Adelaide',
#   'value': 0.1432145,
#   'doc': {'_id': '1372654897280077825',
#    '_rev': '1-05ca8be7e765263b17590421ea9ce025',
#    'id': 1372654897280077825,
#    'user_id': 2843090972,
#    'created_at': '2021-03-18 21:03:24',
#    'text': 'Infectious strains, sluggish vaccine rollouts and a lax attitude to physical distancing have seen cases surge as Eu… https://t.co/9Ldzmot8Z3',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.1432145',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine'}},
#  {'id': '1379939411400396801',
#   'key': 'Adelaide',
#   'value': 0.5414861,
#   'doc': {'_id': '1379939411400396801',
#    '_rev': '1-748afce421c43e8e943a39e42673d409',
#    'id': 1379939411400396801,
#    'user_id': 328453977,
#    'created_at': '2021-04-07 23:29:28',
#    'text': '#auspol Morrison now using the ruse of responding to a sexual harassment report to cover up the vaccine debacle. Ca… https://t.co/A8uTjAEYL7',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.5414861',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine'}},
#  {'id': '1393893283403759617',
#   'key': 'Adelaide',
#   'value': 0.93992174,
#   'doc': {'_id': '1393893283403759617',
#    '_rev': '1-4317732a9ab427b8fdc15cced4597f28',
#    'id': 1393893283403759617,
#    'user_id': 534291241,
#    'created_at': '2021-05-16 11:37:10',
#    'text': 'An interesting #Vaccination fact. #IndiaFightsCOVID19 #CoviShield #Covaxin #VaccineForAll #StayStrongIndia 🙏 https://t.co/qasw6zc6Ku',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.93992174',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'vaccination'}},
#  {'id': '1394586615733919744',
#   'key': 'Adelaide',
#   'value': 0.35523972,
#   'doc': {'_id': '1394586615733919744',
#    '_rev': '1-b498128eb0244cdde1f30ef2dde39cde',
#    'id': 1394586615733919744,
#    'user_id': 290782201,
#    'created_at': '2021-05-18 09:32:14',
#    'text': '@HPA_MV Is vaccination doing what it’s supposed to do. It will be informative to see a breakdown of people who get… https://t.co/vRmHPMYV8N',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]]]'},
#    'sentiment_score': '0.35523972',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'vaccination'}},
#  {'id': '1394616703447752705',
#   'key': 'Adelaide',
#   'value': 0.38703477,
#   'doc': {'_id': '1394616703447752705',
#    '_rev': '1-cb550ebb2a45449729cb52d50035c168',
#    'id': 1394616703447752705,
#    'user_id': 1046659700,
#    'created_at': '2021-05-18 11:31:47',
#    'text': 'The vaccine rollout is a disgrace.',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]]]'},
#    'sentiment_score': '0.38703477',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine'}},
#  {'id': '1395239035191185408',
#   'key': 'Adelaide',
#   'value': 0.15064299,
#   'doc': {'_id': '1395239035191185408',
#    '_rev': '1-58cce277c5da7a784ddf88bbab22c5d0',
#    'id': 1395239035191185408,
#    'user_id': 798994719938265092,
#    'created_at': '2021-05-20 04:44:42',
#    'text': 'I am all for the vaccination, what I am not for is our Australian Government buying the cheapest vaccination for th… https://t.co/LPI2TKH5p8',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.15064299',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'vaccination vaccination'}},
#  {'id': '1395243876198215682',
#   'key': 'Adelaide',
#   'value': 0.955258,
#   'doc': {'_id': '1395243876198215682',
#    '_rev': '1-a03d7ede38021f95c6e7b206168b436a',
#    'id': 1395243876198215682,
#    'user_id': 887184904953282561,
#    'created_at': '2021-05-20 05:03:57',
#    'text': '@SAHealth Vaccine doing good things 🙃',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]]]'},
#    'sentiment_score': '0.955258',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine'}},
#  {'id': '1395276477638221825',
#   'key': 'Adelaide',
#   'value': 0.1140731,
#   'doc': {'_id': '1395276477638221825',
#    '_rev': '1-994b388c21d6523dc5d70e4f214f8002',
#    'id': 1395276477638221825,
#    'user_id': 120050192,
#    'created_at': '2021-05-20 07:13:29',
#    'text': "Vaccine hesitancy reminds me of my car's last service. Dealer called earlier than expected, car was done. I know ze… https://t.co/k3dtoW2Voq",
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]]]'},
#    'sentiment_score': '0.1140731',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine'}},
#  {'id': '1395294258156904449',
#   'key': 'Adelaide',
#   'value': 0.5474219,
#   'doc': {'_id': '1395294258156904449',
#    '_rev': '1-f07b827111fc0442c575196f61dd2ce1',
#    'id': 1395294258156904449,
#    'user_id': 276829665,
#    'created_at': '2021-05-20 08:24:09',
#    'text': '@GregHuntMP Well now many of us over 50 are more confused than ever regarding the vaccine 😳 You are not instilling confidence in many of us',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44213, -35.34897], [138.44213, -34.652564], [138.78019, -34.652564], [138.78019, -35.34897]]]'},
#    'sentiment_score': '0.5474219',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'vaccine'}},
#  {'id': '1342466782594920449',
#   'key': 'Brisbane',
#   'value': 0.56750566,
#   'doc': {'_id': '1342466782594920449',
#    '_rev': '1-572549e999e073dd86ba78106bc83533',
#    'id': 1342466782594920449,
#    'user_id': 1317902652,
#    'created_at': '2020-12-25 13:46:37',
#    'text': '“The tie to where you are from and the drive to get back to it even just for a visit. A booster shot vaccine agains… https://t.co/sZVqZ9pHtV',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.56750566',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1380141919813070859',
#   'key': 'Brisbane',
#   'value': 0.13447255,
#   'doc': {'_id': '1380141919813070859',
#    '_rev': '1-81d2c12f1dadf94c97efa01f4bef883d',
#    'id': 1380141919813070859,
#    'user_id': 2419021166,
#    'created_at': '2021-04-08 12:54:10',
#    'text': 'I just want the vaccine already',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.13447255',
#    'sentiment': 'Negative',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1380313637277986816',
#   'key': 'Brisbane',
#   'value': 0.9221235,
#   'doc': {'_id': '1380313637277986816',
#    '_rev': '1-e2fadde5906e421d1a81d253fd4cb0c2',
#    'id': 1380313637277986816,
#    'user_id': 821309247010979843,
#    'created_at': '2021-04-09 00:16:30',
#    'text': 'For an excellent explanation of the current messaging on the AZ vaccine: https://t.co/b2bSaBIrdF',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.9221235',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1380631283370393600',
#   'key': 'Brisbane',
#   'value': 0.47128966,
#   'doc': {'_id': '1380631283370393600',
#    '_rev': '1-8f95537070aad1acf7fd5e5ccc0f9eb6',
#    'id': 1380631283370393600,
#    'user_id': 23928986,
#    'created_at': '2021-04-09 21:18:43',
#    'text': 'Millions paid in private contracts to ‘support’ the vaccine rollout — but who, what, when, where and why? https://t.co/jS7xM6fDPx',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.47128966',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1380632177067450369',
#   'key': 'Brisbane',
#   'value': 0.80385494,
#   'doc': {'_id': '1380632177067450369',
#    '_rev': '1-4e217a53437637a4c4b56205b772fd5b',
#    'id': 1380632177067450369,
#    'user_id': 23928986,
#    'created_at': '2021-04-09 21:22:16',
#    'text': 'Voters treated like mushrooms as government projects breezy vaccine optimism https://t.co/81EW0h8ip4',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.80385494',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1380994016964014082',
#   'key': 'Brisbane',
#   'value': 0.73314476,
#   'doc': {'_id': '1380994016964014082',
#    '_rev': '1-a36930cc2fa431da271499824496407a',
#    'id': 1380994016964014082,
#    'user_id': 798365943508267008,
#    'created_at': '2021-04-10 21:20:05',
#    'text': 'Took 7 years for the NBN to get to me in inner city Brisbane. Hope the vaccine is a tad speedier https://t.co/bVeEJvTww2',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.73314476',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1387313096394297347',
#   'key': 'Brisbane',
#   'value': 0.3396127,
#   'doc': {'_id': '1387313096394297347',
#    '_rev': '1-cdaac3dcfc3731ad2c7de07dfd3a32d3',
#    'id': 1387313096394297347,
#    'created_at': '2021-04-28 07:49:51',
#    'text': 'Get your flu jab, folks! https://t.co/0eFEAo2eyS',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.3396127',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'jab'}},
#  {'id': '1389825463476887554',
#   'key': 'Brisbane',
#   'value': 0.3372056,
#   'doc': {'_id': '1389825463476887554',
#    '_rev': '1-a847e7d43de1fd3caa49f88ac8c5b25c',
#    'id': 1389825463476887554,
#    'user_id': 2291714040,
#    'created_at': '2021-05-05 06:13:06',
#    'text': '1st jab✅ #COVID19 #COPD https://t.co/zp2Ntl27IJ',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.3372056',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'jab covid19'}},
#  {'id': '1392454425684299777',
#   'key': 'Brisbane',
#   'value': 0.6420873,
#   'doc': {'_id': '1392454425684299777',
#    '_rev': '1-9b8185305986125b7b6efbfd2e16427b',
#    'id': 1392454425684299777,
#    'user_id': 18437440,
#    'created_at': '2021-05-12 12:19:40',
#    'text': 'I wonder if we will end up with vaccine tourism to NZ.',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.6420873',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1392593636219514881',
#   'key': 'Brisbane',
#   'value': 0.3262791,
#   'doc': {'_id': '1392593636219514881',
#    '_rev': '1-0ac3b82b1b21292627fcda157d465ed5',
#    'id': 1392593636219514881,
#    'user_id': 851611483678978048,
#    'created_at': '2021-05-12 21:32:50',
#    'text': 'Vaccination ✔ https://t.co/kdZd44NR9X',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.3262791',
#    'sentiment': 'Negative',
#    'zone': 'Brisbane',
#    'keywords': 'vaccination'}},
#  {'id': '1392676682700443649',
#   'key': 'Brisbane',
#   'value': 0.8599973,
#   'doc': {'_id': '1392676682700443649',
#    '_rev': '1-f2e4c65a5c51011ab2f8999c2fc94577',
#    'id': 1392676682700443649,
#    'user_id': 3259598414,
#    'created_at': '2021-05-13 03:02:50',
#    'text': 'First dose done. Amazing after 17 months to have this technology. Free the vaccine and end vaccine apartheid. https://t.co/PcXqFR3DX0',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.8599973',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine vaccine'}},
#  {'id': '1392733983595659264',
#   'key': 'Brisbane',
#   'value': 0.88072836,
#   'doc': {'_id': '1392733983595659264',
#    '_rev': '1-bc4c06e91ceb0154d934d22a935a5c60',
#    'id': 1392733983595659264,
#    'created_at': '2021-05-13 06:50:32',
#    'text': "'Vaccine strollout'. https://t.co/pGM0bp8ryF",
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.88072836',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1393036515618422786',
#   'key': 'Brisbane',
#   'value': 0.4603274,
#   'doc': {'_id': '1393036515618422786',
#    '_rev': '1-5710ce9435bfd9fc6071197a3f62d069',
#    'id': 1393036515618422786,
#    'created_at': '2021-05-14 02:52:41',
#    'text': '@Brinkley777 @umustrise Exactly. The vaccine is 100 time more dangerous than the virus!!!',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668523, -27.767441], [152.668523, -26.996845], [153.31787, -26.996845], [153.31787, -27.767441]]]'},
#    'sentiment_score': '0.4603274',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1393298586050318337',
#   'key': 'Brisbane',
#   'value': 0.8907675,
#   'doc': {'_id': '1393298586050318337',
#    '_rev': '1-dccb9d07492b8c45139a75b53b4dbec7',
#    'id': 1393298586050318337,
#    'user_id': 2314735854,
#    'created_at': '2021-05-14 20:14:03',
#    'text': 'This will have better take up than the vaccine https://t.co/eIeiYcCZsA',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.8907675',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1393516219987161090',
#   'key': 'Brisbane',
#   'value': 0.5461937,
#   'doc': {'_id': '1393516219987161090',
#    '_rev': '1-360dd5b81ea46552b14cd7495af2139e',
#    'id': 1393516219987161090,
#    'user_id': 65261484,
#    'created_at': '2021-05-15 10:38:51',
#    'text': 'How mRNA became a vaccine game-changer https://t.co/X1zATyECVO',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.5461937',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1394063673904164864',
#   'key': 'Brisbane',
#   'value': 0.045742303,
#   'doc': {'_id': '1394063673904164864',
#    '_rev': '1-43b68bc2fe6dcb84ce7041bdf3ea2116',
#    'id': 1394063673904164864,
#    'user_id': 92633481,
#    'created_at': '2021-05-16 22:54:14',
#    'text': "I'm over 70 and there's no vaccine for me at my clinic.\nhttps://t.co/fIASULdIJt",
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.045742303',
#    'sentiment': 'Negative',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1394591023347605509',
#   'key': 'Brisbane',
#   'value': 0.28562194,
#   'doc': {'_id': '1394591023347605509',
#    '_rev': '1-b75e84031d6cac2d8705f480aa86d04e',
#    'id': 1394591023347605509,
#    'user_id': 865490222745702401,
#    'created_at': '2021-05-18 09:49:44',
#    'text': '@abc730 My GP in inner Brisbane also hasn’t had her vaccine. They prioritised their patients. I would want her to have the vaccine ASAP.',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668523, -27.767441], [152.668523, -26.996845], [153.31787, -26.996845], [153.31787, -27.767441]]]'},
#    'sentiment_score': '0.28562194',
#    'sentiment': 'Negative',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine vaccine'}},
#  {'id': '1394744203909816321',
#   'key': 'Brisbane',
#   'value': 0.49240708,
#   'doc': {'_id': '1394744203909816321',
#    '_rev': '1-3f6450c7ed9ce8093485eb40bbef2477',
#    'id': 1394744203909816321,
#    'user_id': 2314735854,
#    'created_at': '2021-05-18 19:58:25',
#    'text': 'This does not matter until we have herd immunity.  Can we focus on vaccination before letting the virus in. https://t.co/ZHgk4a3rmm',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.49240708',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccination'}},
#  {'id': '1394933698504531969',
#   'key': 'Brisbane',
#   'value': 0.45431608,
#   'doc': {'_id': '1394933698504531969',
#    '_rev': '1-26858381a0d7a8fccfc632a665481804',
#    'id': 1394933698504531969,
#    'user_id': 1648991198,
#    'created_at': '2021-05-19 08:31:24',
#    'text': "These small Qld businesses who aren't letting consumers in if they have received a vaccination. \n\nHow dumb and ridi… https://t.co/WrX59LUZyv",
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.45431608',
#    'sentiment': 'Neutral',
#    'zone': 'Brisbane',
#    'keywords': 'vaccination'}},
#  {'id': '1394970285657427975',
#   'key': 'Brisbane',
#   'value': 0.8869456,
#   'doc': {'_id': '1394970285657427975',
#    '_rev': '1-e664d9ff30f3090c8a4349d4e7f8ff66',
#    'id': 1394970285657427975,
#    'user_id': 1250331934242123776,
#    'created_at': '2021-05-19 10:56:48',
#    'text': 'All good to go for my first AZ jab tomorrow!!! https://t.co/NvONl3If9f',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.8869456',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'jab'}},
#  {'id': '1395155561822396416',
#   'key': 'Brisbane',
#   'value': 0.10452026,
#   'doc': {'_id': '1395155561822396416',
#    '_rev': '1-f187be0878c6690b14cdfc8e60750cb4',
#    'id': 1395155561822396416,
#    'user_id': 23935607,
#    'created_at': '2021-05-19 23:13:01',
#    'text': "Was going to reply to a Rowland tweet about the vaccine but decided I didn't want my menchies wrekt",
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.10452026',
#    'sentiment': 'Negative',
#    'zone': 'Brisbane',
#    'keywords': 'vaccine'}},
#  {'id': '1395241232310231040',
#   'key': 'Brisbane',
#   'value': 0.8488165,
#   'doc': {'_id': '1395241232310231040',
#    '_rev': '1-45322c6c4e4f1e5fe245099d2135afa7',
#    'id': 1395241232310231040,
#    'user_id': 1250331934242123776,
#    'created_at': '2021-05-20 04:53:26',
#    'text': '5555 just spent the 15 mins post jab in the clinic waiting room recording messages in Thai to my friends!!! 🇹🇭🤣🤣🤣',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.8488165',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'jab'}},
#  {'id': '1395255358751350784',
#   'key': 'Brisbane',
#   'value': 0.71205145,
#   'doc': {'_id': '1395255358751350784',
#    '_rev': '1-ca8e969539ac1fafed78460699fd8626',
#    'id': 1395255358751350784,
#    'user_id': 1250331934242123776,
#    'created_at': '2021-05-20 05:49:34',
#    'text': '@AnthroPunk Nice! Nothing so far, just a little soreness where the jab went. The Nurse said any side effects are more likely tomorrow.',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668523, -27.767441], [152.668523, -26.996845], [153.31787, -26.996845], [153.31787, -27.767441]]]'},
#    'sentiment_score': '0.71205145',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'jab'}},
#  {'id': '1395281735194091520',
#   'key': 'Brisbane',
#   'value': 0.8418074,
#   'doc': {'_id': '1395281735194091520',
#    '_rev': '1-9accb1c8b26039631bb3252f6acd85da',
#    'id': 1395281735194091520,
#    'user_id': 2314735854,
#    'created_at': '2021-05-20 07:34:23',
#    'text': 'Well done! @ScottMorrisonMP @GregHuntMP we need to get a wriggle on with our national vaccination campaign... NSW a… https://t.co/fNbT3VBC28',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668523, -27.767441], [152.668523, -26.996845], [153.31787, -26.996845], [153.31787, -27.767441]]]'},
#    'sentiment_score': '0.8418074',
#    'sentiment': 'Positive',
#    'zone': 'Brisbane',
#    'keywords': 'vaccination'}},
#  {'id': '1396405550334681093',
#   'key': 'Brisbane',
#   'value': 0.12651047,
#   'doc': {'_id': '1396405550334681093',
#    '_rev': '1-14cb7bc7941fd80235a7fd60231d4358',
#    'id': 1396405550334681093,
#    'user_id': 1108565574,
#    'created_at': '2021-05-23 10:00:01',
#    'text': 'Someone told me today they heard so far only one percent of the population have had the second jab.. Anybody else h… https://t.co/ZO5sKqC7vc',
#    'place': {'type': 'city',
#     'name': 'Brisbane',
#     'fullname': 'Brisbane, Queensland',
#     'bounding_box': '[[[152.668522848, -27.767440994], [153.31787024, -27.767440994], [153.31787024, -26.996844991], [152.668522848, -26.996844991]]]'},
#    'sentiment_score': '0.12651047',
#    'sentiment': 'Negative',
#    'zone': 'Brisbane',
#    'keywords': 'jab'}},
#  {'id': '1369423140431011848',
#   'key': 'Canberra',
#   'value': 0.10142213,
#   'doc': {'_id': '1369423140431011848',
#    '_rev': '1-a0887611b5ec313f22721190abc3167c',
#    'id': 1369423140431011848,
#    'user_id': 30634725,
#    'created_at': '2021-03-09 23:01:33',
#    'text': '#Canberra cancer doctor Paul Craft is the second person in the ACT to get the @AstraZeneca vaccine after… https://t.co/E9BU8zfjQ9',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.10142213',
#    'sentiment': 'Negative',
#    'zone': 'Canberra',
#    'keywords': 'vaccine'}},
#  {'id': '1378706705588973570',
#   'key': 'Canberra',
#   'value': 0.4362438,
#   'doc': {'_id': '1378706705588973570',
#    '_rev': '1-083fdea7c1626858559a899d4da80d24',
#    'id': 1378706705588973570,
#    'user_id': 2430501032,
#    'created_at': '2021-04-04 13:51:08',
#    'text': 'China winning battle in Pacific https://t.co/4NtyxrJpxc With slow start to Aus vaccination program I can’t see Aus… https://t.co/4j7MC9Ws7a',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.4362438',
#    'sentiment': 'Neutral',
#    'zone': 'Canberra',
#    'keywords': 'vaccination'}},
#  {'id': '1387161126199201792',
#   'key': 'Canberra',
#   'value': 0.93703926,
#   'doc': {'_id': '1387161126199201792',
#    '_rev': '1-7fced0868718c95b36783f8dd289821e',
#    'id': 1387161126199201792,
#    'user_id': 1126758908,
#    'created_at': '2021-04-27 21:45:59',
#    'text': 'AOC Welcomes Olympic Athlete Vaccination, and so do sport loving Australians who want our Olympians and Paraolympia… https://t.co/vNUELKtf5I',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.93703926',
#    'sentiment': 'Positive',
#    'zone': 'Canberra',
#    'keywords': 'vaccination'}},
#  {'id': '1388029946988163083',
#   'key': 'Canberra',
#   'value': 0.56497705,
#   'doc': {'_id': '1388029946988163083',
#    '_rev': '1-b79e350789d9c28aacf97c4ae613342b',
#    'id': 1388029946988163083,
#    'user_id': 3414339592,
#    'created_at': '2021-04-30 07:18:22',
#    'text': 'Can we have a vaccine that has Zero chance of death or ICU, even if that means some mild flu like cases',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.56497705',
#    'sentiment': 'Neutral',
#    'zone': 'Canberra',
#    'keywords': 'vaccine'}},
#  {'id': '1388412419014234112',
#   'key': 'Canberra',
#   'value': 0.6262845,
#   'doc': {'_id': '1388412419014234112',
#    '_rev': '1-df0e3e4d0fd0bfaac14ee91dffa1fec1',
#    'id': 1388412419014234112,
#    'user_id': 3414339592,
#    'created_at': '2021-05-01 08:38:10',
#    'text': 'I still remember when the pm said his mom got vaccine shot. Will he treat him this way? https://t.co/xgczi8QLsl',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.6262845',
#    'sentiment': 'Neutral',
#    'zone': 'Canberra',
#    'keywords': 'vaccine'}},
#  {'id': '1388674127309926400',
#   'key': 'Canberra',
#   'value': 0.019622564,
#   'doc': {'_id': '1388674127309926400',
#    '_rev': '1-05025c727a8bcb8121c61d81d133cd9f',
#    'id': 1388674127309926400,
#    'user_id': 1362891607,
#    'created_at': '2021-05-02 01:58:06',
#    'text': 'Is it normal 3 weeks after having a flu jab to still be experiencing pain in ones arm?',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.019622564',
#    'sentiment': 'Negative',
#    'zone': 'Canberra',
#    'keywords': 'jab'}},
#  {'id': '1390839484359614468',
#   'key': 'Canberra',
#   'value': 0.8997832,
#   'doc': {'_id': '1390839484359614468',
#    '_rev': '1-b5a7b9e893889afab2aa1764d4cdf89c',
#    'id': 1390839484359614468,
#    'user_id': 169014749,
#    'created_at': '2021-05-08 01:22:28',
#    'text': 'First Pfizer jab. Got a lollypop. System works pretty well. @ Garran Oval https://t.co/GAANepBx0p',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.8997832',
#    'sentiment': 'Positive',
#    'zone': 'Canberra',
#    'keywords': 'jab'}},
#  {'id': '1390911678628306946',
#   'key': 'Canberra',
#   'value': 0.47488192,
#   'doc': {'_id': '1390911678628306946',
#    '_rev': '1-ea86f19cbfd2ea5c7b46c2b14f8850f5',
#    'id': 1390911678628306946,
#    'user_id': 3414339592,
#    'created_at': '2021-05-08 06:09:20',
#    'text': 'Safety and immunogenicity of a recombinant tandem-repeat dimeric RBD-based protein subunit vaccine (ZF2001) against… https://t.co/SPjmNuQrso',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.47488192',
#    'sentiment': 'Neutral',
#    'zone': 'Canberra',
#    'keywords': 'vaccine'}},
#  {'id': '1392416908213772290',
#   'key': 'Canberra',
#   'value': 0.4705094,
#   'doc': {'_id': '1392416908213772290',
#    '_rev': '1-a389517fbdc5e989d33a1ca38cb16c14',
#    'id': 1392416908213772290,
#    'user_id': 23401326,
#    'created_at': '2021-05-12 09:50:35',
#    'text': "I'm not too concerned about vaccination progress right now because overseas travel prospects are minimal. BUT as ot… https://t.co/w1KPAQB44c",
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.4705094',
#    'sentiment': 'Neutral',
#    'zone': 'Canberra',
#    'keywords': 'vaccination'}},
#  {'id': '1395193866421035008',
#   'key': 'Canberra',
#   'value': 0.72585267,
#   'doc': {'_id': '1395193866421035008',
#    '_rev': '1-3a98f86ec11de93dd628949244f44b2c',
#    'id': 1395193866421035008,
#    'user_id': 125515417,
#    'created_at': '2021-05-20 01:45:13',
#    'text': 'Meet the Four Kinds of People Holding Us Back From Full Vaccination https://t.co/GjMBMnSG2K',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.72585267',
#    'sentiment': 'Positive',
#    'zone': 'Canberra',
#    'keywords': 'vaccination'}},
#  {'id': '1395202118806478852',
#   'key': 'Canberra',
#   'value': 0.7506791,
#   'doc': {'_id': '1395202118806478852',
#    '_rev': '1-fda0872702825c4cab306c1294851d45',
#    'id': 1395202118806478852,
#    'user_id': 25971449,
#    'created_at': '2021-05-20 02:18:01',
#    'text': 'Still interested in knowing which vaccine Jenny Morrison got.',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.9959216, -35.480260417], [149.263643456, -35.480260417], [149.263643456, -35.147699163], [148.9959216, -35.147699163]]]'},
#    'sentiment_score': '0.7506791',
#    'sentiment': 'Positive',
#    'zone': 'Canberra',
#    'keywords': 'vaccine'}},
#  {'id': '1395293664553828357',
#   'key': 'Canberra',
#   'value': 0.8115623,
#   'doc': {'_id': '1395293664553828357',
#    '_rev': '1-c0fa9cec1dd4921e66bf47e6a0125f25',
#    'id': 1395293664553828357,
#    'user_id': 2224376731,
#    'created_at': '2021-05-20 08:21:47',
#    'text': 'Now that’s incentivisation! I would be happy to get a jab before every kebab.',
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.995922, -35.48026], [148.995922, -35.147699], [149.263643, -35.147699], [149.263643, -35.48026]]]'},
#    'sentiment_score': '0.8115623',
#    'sentiment': 'Positive',
#    'zone': 'Canberra',
#    'keywords': 'jab'}},
#  {'id': '1395321516527546372',
#   'key': 'Canberra',
#   'value': 0.25867313,
#   'doc': {'_id': '1395321516527546372',
#    '_rev': '1-927e95a860e9d895c82131378e363e05',
#    'id': 1395321516527546372,
#    'user_id': 127374370,
#    'created_at': '2021-05-20 10:12:28',
#    'text': "@scepticalzizi I don't think it really matters. One vaccine may be 10% more effective but is difficult to obtain an… https://t.co/7gTdd6xmv4",
#    'place': {'type': 'city',
#     'name': 'Canberra',
#     'fullname': 'Canberra, Australian Capital Territory',
#     'bounding_box': '[[[148.995922, -35.48026], [148.995922, -35.147699], [149.263643, -35.147699], [149.263643, -35.48026]]]'},
#    'sentiment_score': '0.25867313',
#    'sentiment': 'Negative',
#    'zone': 'Canberra',
#    'keywords': 'vaccine'}},
#  {'id': '1379754539989889025',
#   'key': 'Geelong',
#   'value': 0.24601528,
#   'doc': {'_id': '1379754539989889025',
#    '_rev': '1-ea8660888be8ec492fbec307dc2521d0',
#    'id': 1379754539989889025,
#    'user_id': 349065597,
#    'created_at': '2021-04-07 11:14:51',
#    'text': '“Prompt vaccine rollouts alone will not be enough to achieve this; continued public health measures, such as face m… https://t.co/Pf9qmix0mq',
#    'place': {'type': 'city',
#     'name': 'Geelong',
#     'fullname': 'Geelong, Victoria',
#     'bounding_box': '[[[144.290648992, -38.216796993], [144.44827904, -38.216796993], [144.44827904, -38.048004991], [144.290648992, -38.048004991]]]'},
#    'sentiment_score': '0.24601528',
#    'sentiment': 'Negative',
#    'zone': 'Geelong',
#    'keywords': 'vaccine'}},
#  {'id': '1380379465415499776',
#   'key': 'Geelong',
#   'value': 0.32429785,
#   'doc': {'_id': '1380379465415499776',
#    '_rev': '1-e7bf6dde78fd29816295b5e248f1b31e',
#    'id': 1380379465415499776,
#    'user_id': 349065597,
#    'created_at': '2021-04-09 04:38:05',
#    'text': 'Perspective ... \n“Based on current UK data, the risk of dying from a blood clot following the AZ vaccine stands at… https://t.co/WWWKt6d7MV',
#    'place': {'type': 'city',
#     'name': 'Geelong',
#     'fullname': 'Geelong, Victoria',
#     'bounding_box': '[[[144.290648992, -38.216796993], [144.44827904, -38.216796993], [144.44827904, -38.048004991], [144.290648992, -38.048004991]]]'},
#    'sentiment_score': '0.32429785',
#    'sentiment': 'Negative',
#    'zone': 'Geelong',
#    'keywords': 'vaccine'}},
#  {'id': '1389739368227610625',
#   'key': 'Geelong',
#   'value': 0.30551076,
#   'doc': {'_id': '1389739368227610625',
#    '_rev': '1-6f0eef459c49fcad5fe86fc8fe00ec06',
#    'id': 1389739368227610625,
#    'user_id': 1266002215468101643,
#    'created_at': '2021-05-05 00:31:00',
#    'text': 'Got the flu vaccine this morning and a new script for prep. now debating going out and getting my ass played with f… https://t.co/aHbQwBaMTP',
#    'place': {'type': 'city',
#     'name': 'Geelong',
#     'fullname': 'Geelong, Victoria',
#     'bounding_box': '[[[144.290648992, -38.216796993], [144.44827904, -38.216796993], [144.44827904, -38.048004991], [144.290648992, -38.048004991]]]'},
#    'sentiment_score': '0.30551076',
#    'sentiment': 'Negative',
#    'zone': 'Geelong',
#    'keywords': 'vaccine'}},
#  {'id': '1392241469340078080',
#   'key': 'Geelong',
#   'value': 0.9355866,
#   'doc': {'_id': '1392241469340078080',
#    '_rev': '1-7a36c751b7f5c764546f8e18f348aa60',
#    'id': 1392241469340078080,
#    'user_id': 622747849,
#    'created_at': '2021-05-11 22:13:27',
#    'text': 'Hopefully I will turn into this super hero with the @BillGates #Vaccine 😂😎 #NanoTechnology https://t.co/VCH9wLeGGM',
#    'place': {'type': 'city',
#     'name': 'Geelong',
#     'fullname': 'Geelong, Victoria',
#     'bounding_box': '[[[144.290648992, -38.216796993], [144.44827904, -38.216796993], [144.44827904, -38.048004991], [144.290648992, -38.048004991]]]'},
#    'sentiment_score': '0.9355866',
#    'sentiment': 'Positive',
#    'zone': 'Geelong',
#    'keywords': 'vaccine'}},
#  {'id': '1368106656295358466',
#   'key': 'Hobart',
#   'value': 0.4735807,
#   'doc': {'_id': '1368106656295358466',
#    '_rev': '1-0598407eb6b6185c758c236b674eab8d',
#    'id': 1368106656295358466,
#    'user_id': 330095403,
#    'created_at': '2021-03-06 07:50:19',
#    'text': "Dear @healthgovau, I'm keen to get the vaccine when it's my turn, but can I have the apolitical variant please? I m… https://t.co/hJpHqUbI5U",
#    'place': {'type': 'city',
#     'name': 'Hobart',
#     'fullname': 'Hobart, Tasmania',
#     'bounding_box': '[[[147.133660416, -43.014122643], [147.613383232, -43.014122643], [147.613383232, -42.655375527], [147.133660416, -42.655375527]]]'},
#    'sentiment_score': '0.4735807',
#    'sentiment': 'Neutral',
#    'zone': 'Hobart',
#    'keywords': 'vaccine'}},
#  {'id': '1394924286649925635',
#   'key': 'Hobart',
#   'value': 0.2930116,
#   'doc': {'_id': '1394924286649925635',
#    '_rev': '1-7da62ddcba4a9b706f071d35b0b799b1',
#    'id': 1394924286649925635,
#    'user_id': 1251693247,
#    'created_at': '2021-05-19 07:54:01',
#    'text': 'Vaccine लाए पछि अलि राम्री देखिनु भयो 😊 https://t.co/rOWhAInpOQ',
#    'place': {'type': 'city',
#     'name': 'Hobart',
#     'fullname': 'Hobart, Tasmania',
#     'bounding_box': '[[[147.133660416, -43.014122643], [147.613383232, -43.014122643], [147.613383232, -42.655375527], [147.133660416, -42.655375527]]]'},
#    'sentiment_score': '0.2930116',
#    'sentiment': 'Negative',
#    'zone': 'Hobart',
#    'keywords': 'vaccine'}},
#  {'id': '1395246317417365504',
#   'key': 'Hobart',
#   'value': 0.32435155,
#   'doc': {'_id': '1395246317417365504',
#    '_rev': '1-d2b7a0cccbb52c03843b0b849360abf5',
#    'id': 1395246317417365504,
#    'user_id': 867875622,
#    'created_at': '2021-05-20 05:13:39',
#    'text': '@jonkudelka Does that mean I’m getting a “Morrison Jab” tomorrow. I’m not so sure about this now. Maybe it’ll cause… https://t.co/mO8TFERqo9',
#    'place': {'type': 'city',
#     'name': 'Hobart',
#     'fullname': 'Hobart, Tasmania',
#     'bounding_box': '[[[147.13366, -43.014123], [147.13366, -42.655376], [147.613383, -42.655376], [147.613383, -43.014123]]]'},
#    'sentiment_score': '0.32435155',
#    'sentiment': 'Negative',
#    'zone': 'Hobart',
#    'keywords': 'jab'}},
#  {'id': '1344054674458996736',
#   'key': 'Melbourne',
#   'value': 0.31983945,
#   'doc': {'_id': '1344054674458996736',
#    '_rev': '1-4cd32382860aa96739deae358ef01dc7',
#    'id': 1344054674458996736,
#    'user_id': 133957901,
#    'created_at': '2020-12-29 22:56:20',
#    'text': 'So It’s Operation Warp Speed but the distribution relies on carrier pigeon to get the vaccine into people’s arms?… https://t.co/pMNcpvl6SV',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.31983945',
#    'sentiment': 'Negative',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1349262906425163777',
#   'key': 'Melbourne',
#   'value': 0.97308856,
#   'doc': {'_id': '1349262906425163777',
#    '_rev': '1-36eaf100269706607c3ebf4a2cab2c1e',
#    'id': 1349262906425163777,
#    'user_id': 154825713,
#    'created_at': '2021-01-13 07:51:59',
#    'text': 'Given the choice, which vaccine would you prefer? #COVID19Aus #vaccinationCovid #CoronaVaccine',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.97308856',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1361889719127171074',
#   'key': 'Melbourne',
#   'value': 0.8415947,
#   'doc': {'_id': '1361889719127171074',
#    '_rev': '1-31d27f8d9cc2a1ad7c6d788b00a2ea27',
#    'id': 1361889719127171074,
#    'user_id': 435712488,
#    'created_at': '2021-02-17 04:06:26',
#    'text': 'Alright, who’s @ on Wickr has the vaccine hookup?',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.8415947',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1363269851582636032',
#   'key': 'Melbourne',
#   'value': 0.18240893,
#   'doc': {'_id': '1363269851582636032',
#    '_rev': '1-a5098af68ae4de52b73d96d4d0f9c3c7',
#    'id': 1363269851582636032,
#    'user_id': 435712488,
#    'created_at': '2021-02-20 23:30:35',
#    'text': 'Breaking - Australia starts vaccine rollout today. Elderly first. \nMe - https://t.co/Eimf0Nwi22',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.18240893',
#    'sentiment': 'Negative',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1363443213856604163',
#   'key': 'Melbourne',
#   'value': 0.42549568,
#   'doc': {'_id': '1363443213856604163',
#    '_rev': '1-24f308d911b1d1b606da597e8f545dbc',
#    'id': 1363443213856604163,
#    'user_id': 209870952,
#    'created_at': '2021-02-21 10:59:28',
#    'text': 'Baffling for people to boo at a vaccine that will save lives — let alone a government which has managed to help sta… https://t.co/GcELEtisW9',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.42549568',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1363687945501241351',
#   'key': 'Melbourne',
#   'value': 0.5933353,
#   'doc': {'_id': '1363687945501241351',
#    '_rev': '1-f01b6e0ac1fdc09ac5a41a82239975a4',
#    'id': 1363687945501241351,
#    'user_id': 435712488,
#    'created_at': '2021-02-22 03:11:56',
#    'text': 'All we need is a Contax photo from one of the Kardashians getting the vaccine then boom, no more anti vaxxers',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.5933353',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1365420449685979138',
#   'key': 'Melbourne',
#   'value': 0.8698402,
#   'doc': {'_id': '1365420449685979138',
#    '_rev': '1-9a82b647d31c391c56f9079a92a92947',
#    'id': 1365420449685979138,
#    'created_at': '2021-02-26 21:56:18',
#    'text': '#vaccine #covid_19  #imnext #seemslegit @ Brunswick, Victoria https://t.co/qupbLMvetX',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.8698402',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine covid'}},
#  {'id': '1367359262746316805',
#   'key': 'Melbourne',
#   'value': 0.5276828,
#   'doc': {'_id': '1367359262746316805',
#    '_rev': '1-bd8c46a98079bc029e62bcbbf96a4ed3',
#    'id': 1367359262746316805,
#    'user_id': 86330087,
#    'created_at': '2021-03-04 06:20:27',
#    'text': 'I had the best company waiting at the vaccination clinic 😍🐶 https://t.co/KjhydaLxms',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
# ...
#    '_rev': '1-35e66f247034b239764582a92f0c8a86',
#    'id': 1382277931372711937,
#    'user_id': 1156258419730337792,
#    'created_at': '2021-04-14 10:21:54',
#    'text': 'The Vaccine is Eternal Life.\nBlood &amp; Bone ® 💊 capsules.\nNurturence from the Genome /bacteria.\nNo need for supplemen… https://t.co/30Xd5qZrcu',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.37165123',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1383155621235597312',
#   'key': 'Melbourne',
#   'value': 0.45608926,
#   'doc': {'_id': '1383155621235597312',
#    '_rev': '1-40b35ff1477818c7565695ccf95a5103',
#    'id': 1383155621235597312,
#    'user_id': 115730264,
#    'created_at': '2021-04-16 20:29:32',
#    'text': 'We have another variant coming out of India, by the time the Morrison government gets its vaccine roll out together… https://t.co/Ks6FAGr3y0',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.45608926',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1383692574804774913',
#   'key': 'Melbourne',
#   'value': 0.85180354,
#   'doc': {'_id': '1383692574804774913',
#    '_rev': '1-03589736c87a61f979db08fc3b2b30b1',
#    'id': 1383692574804774913,
#    'user_id': 187866237,
#    'created_at': '2021-04-18 08:03:12',
#    'text': 'Thought I might as well start a nurse vaccination course to keep my awake until my 1:1 with @themaddiep and… https://t.co/h6JKBUTcp8',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.85180354',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccination'}},
#  {'id': '1383967304346574849',
#   'key': 'Melbourne',
#   'value': 0.2118235,
#   'doc': {'_id': '1383967304346574849',
#    '_rev': '1-9f90df7bebb0b6e10e0e7496cfd94f3f',
#    'id': 1383967304346574849,
#    'user_id': 830824554,
#    'created_at': '2021-04-19 02:14:52',
#    'text': 'Please remember to have a two-week gap between taking the flu vaccine and the COVID vaccine.\n\nYou can get your flu… https://t.co/l5oLoWNLjC',
#    'place': {'type': 'neighborhood',
#     'name': 'St Albans',
#     'fullname': 'St Albans, Melbourne',
#     'bounding_box': '[[[144.77871816, -37.768374], [144.83269116, -37.768374], [144.83269116, -37.727568], [144.77871816, -37.727568]]]'},
#    'sentiment_score': '0.2118235',
#    'sentiment': 'Negative',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine covid vaccine'}},
#  {'id': '1383994300241907714',
#   'key': 'Melbourne',
#   'value': 0.09881741,
#   'doc': {'_id': '1383994300241907714',
#    '_rev': '1-720b333f1843af43fb20296bef06a11c',
#    'id': 1383994300241907714,
#    'user_id': 877869048809144321,
#    'created_at': '2021-04-19 04:02:09',
#    'text': "Where's my vaccine, Scomo??",
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.09881741',
#    'sentiment': 'Negative',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1384377628514152448',
#   'key': 'Melbourne',
#   'value': 0.46788907,
#   'doc': {'_id': '1384377628514152448',
#    '_rev': '1-67a2611c9ba5e9072716f36294480b79',
#    'id': 1384377628514152448,
#    'user_id': 187866237,
#    'created_at': '2021-04-20 05:25:21',
#    'text': 'Why did I think it would be a good idea to do a vaccination accreditation??? Oh yeah. I need another job so I can get a mortgage.',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.46788907',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccination'}},
#  {'id': '1384435375586779139',
#   'key': 'Melbourne',
#   'value': 0.4441839,
#   'doc': {'_id': '1384435375586779139',
#    '_rev': '1-3f6fa58cc1b126622af1951f6dddb303',
#    'id': 1384435375586779139,
#    'user_id': 87050404,
#    'created_at': '2021-04-20 09:14:49',
#    'text': 'She ain’t my Premier, but I’m low key loving Gladys going absolutely savage on the federal government’s vaccine rollout. 👀',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.4441839',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1384869832496197636',
#   'key': 'Melbourne',
#   'value': 0.7407907,
#   'doc': {'_id': '1384869832496197636',
#    '_rev': '1-0666223a80eace89801936f4d6c26279',
#    'id': 1384869832496197636,
#    'user_id': 282420017,
#    'created_at': '2021-04-21 14:01:12',
#    'text': 'Got my vaccine yesterday and everything seems fine #GetVaccinated #AstraZeneca https://t.co/Fy70p0WqP7',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.7407907',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1385415051880767495',
#   'key': 'Melbourne',
#   'value': 0.93403,
#   'doc': {'_id': '1385415051880767495',
#    '_rev': '1-a0be6fd1982d53c0940fc354ae73b1ba',
#    'id': 1385415051880767495,
#    'user_id': 809650903800156160,
#    'created_at': '2021-04-23 02:07:42',
#    'text': 'When you make a comment on the Health Ministers Facebook post that you will take the AstraZeneca vaccine, and that… https://t.co/YHOli9L1x0',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.93403',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1385522080163065856',
#   'key': 'Melbourne',
#   'value': 0.70321435,
#   'doc': {'_id': '1385522080163065856',
#    '_rev': '1-77730af05ca3bf285756e3ce1dc9d866',
#    'id': 1385522080163065856,
#    'user_id': 809650903800156160,
#    'created_at': '2021-04-23 09:13:00',
#    'text': 'So update on my Facebook comment where I supported the Astrazeneca vaccine. 💉\n\nI’m actually going to take this one… https://t.co/ibpa60Dzfp',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.70321435',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1385761095894200320',
#   'key': 'Melbourne',
#   'value': 0.37116212,
#   'doc': {'_id': '1385761095894200320',
#    '_rev': '1-e504442582d48bf639307e7c13e6e92a',
#    'id': 1385761095894200320,
#    'user_id': 963289553682317313,
#    'created_at': '2021-04-24 01:02:46',
#    'text': 'I guess there are still many folk taking the vaccine, right? What will it take...?? https://t.co/rCK4Roc0iE',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.37116212',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1386106923343171586',
#   'key': 'Melbourne',
#   'value': 0.45983073,
#   'doc': {'_id': '1386106923343171586',
#    '_rev': '1-423c330b14592e818b6aedb70aab3476',
#    'id': 1386106923343171586,
#    'user_id': 259587697,
#    'created_at': '2021-04-24 23:56:57',
#    'text': 'Vaccination\xa0is not only an individual good, it’s also a societal one. The atmosphere at our vaccination clinics sho… https://t.co/nUNii11BUV',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.45983073',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccination vaccination'}},
#  {'id': '1387155687239651328',
#   'key': 'Melbourne',
#   'value': 0.69230354,
#   'doc': {'_id': '1387155687239651328',
#    '_rev': '1-7076afe07dffec1e34f9e40c066e50e7',
#    'id': 1387155687239651328,
#    'user_id': 612509166,
#    'created_at': '2021-04-27 21:24:22',
#    'text': 'Now that the announcement has been made about athletes getting the vaccine as a priority. Is there any information… https://t.co/iFanLnj0nL',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.69230354',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1387990922260926469',
#   'key': 'Melbourne',
#   'value': 0.6508585,
#   'doc': {'_id': '1387990922260926469',
#    '_rev': '1-91e452ba7762a37caccbc8fb049e6cfc',
#    'id': 1387990922260926469,
#    'user_id': 2882834947,
#    'created_at': '2021-04-30 04:43:18',
#    'text': 'A new high-volume vaccination centre will open in Melbourne’s bustling southeastern suburbs early next week.… https://t.co/rVtJgtuEvp',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.6508585',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccination'}},
#  {'id': '1388661052015931392',
#   'key': 'Melbourne',
#   'value': 0.85394776,
#   'doc': {'_id': '1388661052015931392',
#    '_rev': '1-a18175347432a738cfad2238c1c20736',
#    'id': 1388661052015931392,
#    'user_id': 1292813453610979333,
#    'created_at': '2021-05-02 01:06:09',
#    'text': 'Everyone must watch this speech by humans rights lawyer on vaccine roll out in California \n\nhttps://t.co/NnpGWPDV41',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.85394776',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1389034867795533827',
#   'key': 'Melbourne',
#   'value': 0.87520075,
#   'doc': {'_id': '1389034867795533827',
#    '_rev': '1-31e8f4892c736edea1c215439a0f66c3',
#    'id': 1389034867795533827,
#    'user_id': 21926199,
#    'created_at': '2021-05-03 01:51:34',
#    'text': 'Great to see - If they changed health advice I would have absolutely no problem getting the AstraZeneca vaccine now https://t.co/TZZF7M1wR2',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.87520075',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1389123209321009153',
#   'key': 'Melbourne',
#   'value': 0.984012,
#   'doc': {'_id': '1389123209321009153',
#    '_rev': '1-0330639358983ceab19a9239f96597e7',
#    'id': 1389123209321009153,
#    'user_id': 81915976,
#    'created_at': '2021-05-03 07:42:36',
#    'text': 'Check out this awesome vaccination campaign video from the New Zealand government https://t.co/iht95SwxcQ',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.984012',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccination'}},
#  {'id': '1389357475187466241',
#   'key': 'Melbourne',
#   'value': 0.7554077,
#   'doc': {'_id': '1389357475187466241',
#    '_rev': '1-09bb7727e377cfd6f7101bc516f6f6b5',
#    'id': 1389357475187466241,
#    'user_id': 2882834947,
#    'created_at': '2021-05-03 23:13:29',
#    'text': 'Victoria had its most successful day in vaccine rollout yesterday with almost 7000 jabs delivered. Minister Foley c… https://t.co/pJtX8GHEn2',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.7554077',
#    'sentiment': 'Positive',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1389423901017473026',
#   'key': 'Melbourne',
#   'value': 0.030413836,
#   'doc': {'_id': '1389423901017473026',
#    '_rev': '1-448e2a4614d072068c23a9bfdfabea7e',
#    'id': 1389423901017473026,
#    'user_id': 66680359,
#    'created_at': '2021-05-04 03:37:26',
#    'text': 'Flu vaccine aftermath https://t.co/eEkRlWBN18',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.030413836',
#    'sentiment': 'Negative',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}},
#  {'id': '1389748723664621570',
#   'key': 'Melbourne',
#   'value': 0.53264004,
#   'doc': {'_id': '1389748723664621570',
#    '_rev': '1-bc1e9df2f8f9956ccd48ed79eb150f59',
#    'id': 1389748723664621570,
#    'user_id': 14707794,
#    'created_at': '2021-05-05 01:08:10',
#    'text': 'Just another face in the mass vaccination hub queue.. @normanswan waits to receive his first dose of the AZ vaccine. https://t.co/o2v0wWIn99',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.53264004',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccination vaccine'}},
#  {'id': '1389799199336591364',
#   'key': 'Melbourne',
#   'value': 0.64977866,
#   'doc': {'_id': '1389799199336591364',
#    '_rev': '1-be467282d90c5e5bb0c4901779fecce1',
#    'id': 1389799199336591364,
#    'user_id': 1267838570,
#    'created_at': '2021-05-05 04:28:44',
#    'text': 'First AstraZeneca shot done and dusted 💉\n#coronacoma #rackoffrona #shotinthearm #vaccinationdone✔️ #vaccine… https://t.co/773aIjqzKh',
#    'place': {'type': 'city',
#     'name': 'Melbourne',
#     'fullname': 'Melbourne, Victoria',
#     'bounding_box': '[[[144.593741856, -38.433859306], [145.512528832, -38.433859306], [145.512528832, -37.5112737225], [144.593741856, -37.5112737225]]]'},
#    'sentiment_score': '0.64977866',
#    'sentiment': 'Neutral',
#    'zone': 'Melbourne',
#    'keywords': 'vaccine'}}]

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords


def top_words(textlist,top=10):
    stop_words = stopwords.words('english')
    wordfreqdict={}
    popular=[]
    tokenizer=TweetTokenizer()
    for t in textlist:
        token = tokenizer.tokenize(t)
        for w in token:
            if w not in wordfreqdict.keys():
                wordfreqdict[w]=1
            else:
                wordfreqdict[w]+=1
    sorted_values = sorted(wordfreqdict.values(), reverse=True) # Sort the values
    count=0
    for i in sorted_values:
        for k in wordfreqdict.keys():
            if wordfreqdict[k] == i:
                if len(k)>=5 and k not in popular and k not in stop_words:
                    
                    popular.append(k)
                    count+=1
                
        if count > top:
            break     
    popdict={}
    for p in popular:
        popdict[p]=wordfreqdict[p]
    return popdict
def city_daily_popular_10words():

    city=[]
    tweetlist=get_data(viewType="zone")
    for k in  tweetlist:
        if k["key"] not in city:
            city.append( k["key"])
    alltext={}
    for c in city:
        alltext[c]=[]
    for k in tweetlist:
        for c in city:
            if k["key"]  in c:
                alltext[c].append(k["doc"]["text"])
    popdict={}             
    for c in city:
        popdict[c]=top_words(alltext[c])
    return alltext

# %%
city_daily_popular_10words()
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_covid
# {'Adelaide': ['‘The #COVID19 #pandemic is a stark reminder that #evidence alone is often not enough.’ Read the editorial by… https://t.co/sX6mQ9JMSF',
#   'Listening to @ithinkwellHugh talk about supporting research students working remotely due to #COVID19 Tip: organise… https://t.co/GUIZwpnbrY',
#   '🖤!GIG!🖤 jemmanicolemusic &amp; I will be returning from lockdown for an intimate acoustic show @graceemilyhotel !! 😀😀… https://t.co/aXj5aUizdn',
#   'Covid giveth and covid taketh away',
#   "Tf is going on?! Lockdown from Midnight tonight for 6 days. Hopefully we'll get to enjoy Christmas, if we get to the other side of this 😔",
#   'Hmm 6 days of lockdown, might need to sort some new @lobumusic for you all!',
#   'Lockdown day 2. Cant wait to go back to work tomorrow. 😂 \n@fiit_project 😂 @ Norwood, South Australia https://t.co/NTp4B9GrRy',
#   'Pizza #covid @ Woodville pizza bar https://t.co/aQFCUWSfGV',
#   'Watch out CAHLN.  Stroke Neurology (RAH) represent!\n\n#p.s. Santa started lifting weights  since covid19 @ Royal Ade… https://t.co/6VFSyZO5I0',
#   'Silver lining of Covid19. Wouldn’t have joined this wonderful bunch of people if my old gym didn’t do extended lock… https://t.co/Fn1qANVoWN',
#   'England is so confusing - Adelaide got one cluster that they thought could be linked to the new strain of Covid and… https://t.co/rPginAnxH7',
#   'In light of COVID, can we have some sort of Bluetooth devices that the passengers can connect to so they can choose… https://t.co/Cs3xUXKgpp',
#   'It appears to me that there is,in fact, an early warning sign of people that are Covid infectious but not yet sympt… https://t.co/0pZsCiX9Q1',
#   'Proud to be helping in the RAH COVID Clinic protecting our community with Ben Cahill and Sarah Kemp @CentralAdlLHN… https://t.co/UOsqqauXHQ',
#   'Finally got my first dose of the covid vaccine! Both Pfizer and Astra Zeneca covid vaccines are safe and thoroughly… https://t.co/Wac7dnmuwl',
#   'Covid Vaccine 💉✅ #RollUpSA #FirstDose #FrontLineHealthWorker',
#   'Delayed by #Covid but finally @BarefootToBoots container off to #Kakuma. School supplies, books, football &amp; sports… https://t.co/nyPjeNQaz0',
#   'Had my COVID 19 Vaccination today thanks Gunza !@CentralAdlLHN #rollup #Belikeus #heartandlung https://t.co/6OQ7UlwS86',
#   'Is there a way I can just buy my own COVID-19 vaccine and take to my GP to have it administered? If enough of us cr… https://t.co/mJYSsKJ9YB',
#   'Had my second COVID test today, or for the tinfoil hat brigade, my second network connectivity and speed test. It w… https://t.co/YfRxkBwNlC',
#   'Last tour (that covid didn’t fuck up) was insane. @sekushistudios and I are set to make my next trip the best one y… https://t.co/fwoNrrttHw',
#   'Australia cuts direct flights from India after mass COVID outbreak https://t.co/bkypB0sLfS',
#   'Went out &amp; explored my home country &amp; absolutely LOVED it!! One positive of covid &amp; staying on home soil 💜🥰💜 flinde… https://t.co/m0WC3AS1UM',
#   'I’m starting to freak out a little again about covid....... not helped by hearing about the people dying in the hos… https://t.co/lKUTlQzVwR',
#   'Anyone thought about Covid-19 vaccines passing the drug tests?? @Tokyo2020 @LizzyLegsEllis',
#   'Taylor responds measured and effectively to what is a challenging situation in India with IPL COVID-19 chaos...incr… https://t.co/Yvwc8uS486',
#   'At least we know in NSW that Gladys won’t chuck the entire state into lockdown https://t.co/OioGvImo0d',
#   'Subtitles available currently in French and English, other translations in progress 👍. Next videos, more Covid-19 r… https://t.co/HxOHbVKl8c',
#   'We have a family wedding in Coffs Harbour in a couple of months. 3500km is a long drive but with this latest Covid… https://t.co/pp3Ek3xRq1',
#   'Thebby is no longer an option. This new location has to be or home. We’ve seen during Covid our fans and members wi… https://t.co/JNiIiCUEhw',
#   'My wife had to go by ambulance to the hospital because she has tested positive to Covid-19. Things keep getting wor… https://t.co/76Tb4SX1Fh',
#   'A streaker with a mask on just before the 3rd quarter starts. You have to applaud Covid safe drunken idiots!',
#   'I had a dream about Covid-19 vaccination. The needle was massive! 😱😳',
#   'Candice Bergen turns 75. The Nordic Hollywood beauty who has it all, and had it all. She wrote a lockdown dog-walki… https://t.co/J2Uj75JMYT',
#   'Mums aged care facility booked for covid vaccination this week, hmm watch this space #COVID19Vaccination #covidau',
#   'My son has tested positive for Covid-19 now https://t.co/rjkGegABZ8',
#   'The only reason Australia has done so well during covid is because of the unions and states #abc730 @sallymcmanus',
#   'Our Wayville COVID Clinic Nurses and team IND21 celebration #BeLikeUs #IND21 @LesleyDwyerCEO @CentralAdlLHN https://t.co/SDzBnpJvm7',
#   'I salute our Refugee Health centre Nurses today always stepping up especially with COVID 19 challenges #IND21… https://t.co/brfCFNE2pz',
#   'As a side effect of Covid-19 my family (4) got themselves big, ugly tattoos (after recovery). Don’t ask 😂. I think… https://t.co/yAbu5zGnf7',
#   'Can we all agree that mucorales are not “black fungus”?\n\nIn the midst of the COVID pandemic, India is battling a su… https://t.co/sRR2zLtngi',
#   '#Australians would go for this. A free beer or wine might also work. #COVID19 https://t.co/0W0vYHo1mG',
#   'I am fully vaccinated! Both Covid 19 and my Flu injection! Ready to support our community so Rollup! #rollupsa… https://t.co/7KhRmQJb00',
#   'RIP Dr Chawla. This brave doctor lost her unborn child and then her own life succumbing to covid. Stark warning for… https://t.co/D3Fptc4cgA',
#   'Tonight!!! Women of all ages invited 💕 Tickets still available at the website. \nhttps://t.co/z7JXdN1swJ\n\n For Covid… https://t.co/9C4xxIj7Ar',
#   'Covid complacency is plain to see everywhere here in ADL. QR scanning can help reduce the need for extended lock do… https://t.co/bTiVqFE8sA',
#   "Spent covid taking my daughter swimming in the freezing weather. Didn't realise I would miss it. Must be crazy.… https://t.co/1FeSnLOXsg",
#   'Booked my covid vaccination earliest June 18',
#   'Watching the daily SA covid presser &amp; I can’t help but idly wonder why Stephen Wade always sounds like he’s either… https://t.co/tDx2XV1V9P',
#   'If #COVID19 taught me I’m touching my face 20+ times/h today’s email outage taught me I’m touching my phone way mor… https://t.co/biM4iRJiXd',
#   'To get vaccinated for covid19 in Australia you have to be proactive\n\nThis @ScottMorrisonMP govt is incompetent, use… https://t.co/WSfLEpuK6f',
#   'Has shonky Federal LNP government put out tenders to private companies re our covid vaccination passport? UK is bei… https://t.co/KZx5cdrrP3',
#   'Wish there was a news channel that didn’t broadcast anything covid related or speculation about when borders are op… https://t.co/z0ZyWPnfFp',
#   '@HPA_MV A more powerful question is “Is getting vaccinated give  me better chance to survive COVID-19?” \nWe need to… https://t.co/iUz2d1DtfC',
#   '@LindaMelisande Second Pfizer on Saturday at RAH staff covid hub (clinic has now moved to Adelaide Showgrounds for… https://t.co/D4V9e9mgkH',
#   "I've now had three different people ask me if I only got the covid vax because my work wanted me to, which is, uh,… https://t.co/km846hvJya",
#   '#TokyoTogether So happy for this crew💛💚\n\nTeam named in March ‘20, but then COVID + Games postponement... \n\n15 month… https://t.co/eCWvi9eQrg',
#   'Communicating with patients and the public about COVID-19 vaccine safety: recommendations from the Collaboration on… https://t.co/Ln834CCZQz'],
#  'Ballarat': ['One thing #rona #lockdown had taught me is how much a #love a #dip on the #weekends with #poy our first one back to… https://t.co/sV5s7Ilkth',
#   'Somebody did a shit in the staff dunnies, wayyyy worse than covid 😆😆😆😆 #auspol #welcomeback',
#   '#sunday #walkies and #roly the #dog and I playing our new #favourite #covid #game discarded #mask or #underwear giv… https://t.co/MZzZk46PUv',
#   'Watch my fun Lockdown 2020 Artwork #artinspiration #easyart #arttechniques #learntopaint #paintlikeme #funart… https://t.co/gO0YLjMJ0p'],
#  'Brisbane': ['This is our global crisis. In my time. How can I help?  #supportoneanother #COVID19au #covid19australia #COVIDー19 https://t.co/9vH5SG7Nyj',
#   'This! @DrKGregorevic with some sound, sensible advice for coping with COVID-19. A timely reminder for me to exercis… https://t.co/OWBNuEHJ2r',
#   'Great to chat with @adnews about working from home during Covid-19 https://t.co/o8ATcoo4BJ',
#   'To all my Indian friends, If you gonna survive the loneliness due to Covid-19. Then, my friend you would come out a… https://t.co/blc8VbAJhE',
#   'Dr. Norman Swan being interviewed on ABC News Lunchtime bulletin re the coronavirus outbreaks in Victoria and he is… https://t.co/xuQAdn5fgJ',
#   'Think Mobility is committed to keeping our staff and our clients safe especially during Covid-19. \n\nHere is our Key… https://t.co/0W2zAFpoFa',
#   'The end of a #covid19 Child Protection Week in Qld .. a small celebration of all the good souls and positive storie… https://t.co/yj76JRDWEu',
#   "So I have this theory that most of us are now completely burnt out /over this year mainly because we haven't had a holiday since pre Covid.",
#   'Folks banging on about ‘5G chips’ being in the various coronavirus vaccines is really some K. Eric Drexler ‘Engines… https://t.co/uW0mMmMJt3',
#   'Lockdown office.\n\nDay 1 @ Brisbane, Queensland, Australia https://t.co/7IWlzUC55o',
#   'Covid lockdown pasta making , it’s been a while, still got it 😜\n\n#covidlockdown #pasta #food #cooking #redwinehelps… https://t.co/tTlUR4MA0M',
#   'Lockdown day 2 @ South Bank, Brisbane https://t.co/NvmFG3yXMv',
#   'Lockdown beers thanks to @happyvalleybrewco awesome drop, first one I’ve tried won’t be the last.\n\n#covid_19… https://t.co/EqV2QlfOJo',
#   "While most people are in lockdown, I'm out 'excercising' 😂 the water is just so peaceful ❤️ @ Kangaroo Point Cliffs https://t.co/Jcj4AdWjz8",
#   "And I'm back (during the day this time) lockdown isn't even over yet, yet every man and his dog is out. I mean, I'm… https://t.co/9u0ZUFh5jt",
#   'Do you have to pay tour employees when they cannot work due to a government enforced lockdown?  #brisbanelockdown… https://t.co/fV2dmovIRD',
#   'Why hasn’t the PM stopped Craig Kelly MO from sharing misinformation about COVID. About time @ScottMorrisonMP start… https://t.co/sRQSp6HsIL',
#   'Just got flipped off by the first covid vaccine recipient in australia. How’s your day going?',
#   'Why does @ScottMorrisonMP get the COVID shot. He’s not in the high risk or a frontline worker so why is he getting… https://t.co/I0J1ZnfiqI',
#   'RT @workforcesoton Thousands of healthcare workers have died in the line of duty of care for patients with #COVID19… https://t.co/551UNf9f0q',
#   'COVID upended the employment market. Now is the time for those in recruitment roles to #ChooseToChallenge how job c… https://t.co/YboKpdgGZN',
#   'My nickname at work is ‘covid sufferer’ and I don’t know how I feel about it.',
#   'Just had my second COVID-19 vaccination. It appears I have one of the little known side effects. I’m all good. https://t.co/eek71M2vMb',
#   'What we have learnt during #COVID19 will have us in a better place in the future #MedRadJclub',
#   '#BREAKING: Brisbane will go into a 3 day lockdown from 5PM tonight after 4 new cases of community transmission. \n\n2… https://t.co/RX8p5mCbLu',
#   'Lockdown in Brisbane means now would be a really good time to release that patch @CyberpunkGame',
#   'Feeling down about the lockdown??.. take a moment and listen/watch this... and breathe. Another gorgeous moment cap… https://t.co/HfBW79DbLs',
#   '4 cases and back into lockdown we go',
#   'Cyberpunk delivering lockdown goodness. Now to wait for this 44GB patch to download in the hope the game doesn’t ra… https://t.co/V1xshvScb9',
#   'Lockdown is going well. #kovidkaraoke https://t.co/Ujwivnx4eK',
#   'Day 1 of a 3 day *circuit breaking* snap lockdown in Brisbane.. schools closed, so back to our Covid ways, of a mor… https://t.co/I8t9ZkonWK',
#   'Joining the @australianlabor Special Platform Conference from the couch during the Greater Brisbane Lockdown. Looki… https://t.co/aWAHCauMtV',
#   'a very happy lockdown puppy!!! too many toys to throw this morning! but she is always silent during zooms which is… https://t.co/1pX2owWrw6',
#   'with every lockdown the little piece of hope that I’ll be back to make music with my friends dies',
#   'Whilst I completely understand (and support) why Brisbane has had to go back into lockdown, it’s completely fucked… https://t.co/WAb5bl2hqo',
#   'The last thing you need when you’re stuck at home on your birthday in lockdown is getting a call from some Hong Kon… https://t.co/C3ZiIJ4IWK',
#   'After Covid swab beer!!! - Drinking a XPA by @balterbrewers @ Marriott Brisbane Hotel Quarantine  — https://t.co/wAddmLQDgq',
#   'I’ve realised that doing this lockdown without alcohol was a really bad idea.']}

# %%
get_data(db="no_keywords",viewType="zone")
# Out:
# Username: admin
# Databases: ['tweets_covid', 'tweets_keywords', 'tweets_no_keywords', 'tweets_raw', 'tweets_vaccine']
# Accessing db: tweets_no_keywords
# [{'id': '1002519101057593345',
#   'key': 'Adelaide',
#   'value': 0.974139,
#   'doc': {'_id': '1002519101057593345',
#    '_rev': '1-8a9a6c3c3630b9429653cb886fa419c3',
#    'id': 1002519101057593345,
#    'user_id': 3181196792,
#    'created_at': '2018-06-01 11:55:54',
#    'text': 'Love this !!!\nAdelaide cops 👏 https://t.co/4sRQnOft2W',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.974139',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1003848262875373569',
#   'key': 'Adelaide',
#   'value': 0.87751937,
#   'doc': {'_id': '1003848262875373569',
#    '_rev': '1-ede3d1ede3e3e7b1776ab79be109acb7',
#    'id': 1003848262875373569,
#    'user_id': 3181196792,
#    'created_at': '2018-06-05 03:57:31',
#    'text': 'Wow 😟 https://t.co/gSddZeoDtA',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.87751937',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1005145955677585408',
#   'key': 'Adelaide',
#   'value': 0.9144138,
#   'doc': {'_id': '1005145955677585408',
#    '_rev': '1-22be5492ca7d7d593ea8d6d4cf7ec4bf',
#    'id': 1005145955677585408,
#    'user_id': 3181196792,
#    'created_at': '2018-06-08 17:54:05',
#    'text': 'Gold luck to this Coffin Bay , SA Guy 😊👍 https://t.co/7TB1XqaOBF',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9144138',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1006506052517445632',
#   'key': 'Adelaide',
#   'value': 0.2859127,
#   'doc': {'_id': '1006506052517445632',
#    '_rev': '1-b4a962247252fa9641f447e8e4a42a10',
#    'id': 1006506052517445632,
#    'user_id': 3181196792,
#    'created_at': '2018-06-12 11:58:37',
#    'text': 'This show is getting so boring! 💤 Lets Really STIR the pot and vote Erin for the date 😱🤣👍  #LoveIslandAU',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.2859127',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1007639989511835648',
#   'key': 'Adelaide',
#   'value': 0.98329234,
#   'doc': {'_id': '1007639989511835648',
#    '_rev': '1-4ec63ca45a697d129ab4bf9a61355d46',
#    'id': 1007639989511835648,
#    'user_id': 3181196792,
#    'created_at': '2018-06-15 15:04:29',
#    'text': 'Adelaide Boy James Mraz in London #Legend https://t.co/vcXb7l3beC',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.98329234',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1008970349310963712',
#   'key': 'Adelaide',
#   'value': 0.95155305,
#   'doc': {'_id': '1008970349310963712',
#    '_rev': '1-2bb4816f7e5052daf6cdc8f0e69a90b7',
#    'id': 1008970349310963712,
#    'user_id': 3181196792,
#    'created_at': '2018-06-19 07:10:51',
#    'text': 'Ready to have some fun Adelaide?\nHelp support a great cause in beyondblue at this years Out of the Blue Gala Ball!… https://t.co/f5yuG3WZCv',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.95155305',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1009823487387566080',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1009823487387566080',
#    '_rev': '1-3fd4e394400609a86b7dd0d079452645',
#    'id': 1009823487387566080,
#    'user_id': 3181196792,
#    'created_at': '2018-06-21 15:40:55',
#    'text': '😊👍 https://t.co/rCWiYxrNEA',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1012626540272631815',
#   'key': 'Adelaide',
#   'value': 0.97655344,
#   'doc': {'_id': '1012626540272631815',
#    '_rev': '1-88eb7be7c37d36c870b88cce5175a84a',
#    'id': 1012626540272631815,
#    'user_id': 3181196792,
#    'created_at': '2018-06-29 09:19:15',
#    'text': 'Great news !! https://t.co/1ii5Sd7WNW',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.97655344',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1012629212040007680',
#   'key': 'Adelaide',
#   'value': 0.9925445,
#   'doc': {'_id': '1012629212040007680',
#    '_rev': '1-3b6e0a4319dfdbbd55dd43300064957c',
#    'id': 1012629212040007680,
#    'user_id': 3181196792,
#    'created_at': '2018-06-29 09:29:52',
#    'text': 'Sounds like a great program ! https://t.co/pDiYU54aTd',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9925445',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1013288048446980096',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1013288048446980096',
#    '_rev': '1-80a53b4c18c2a1c8552038287dc40d40',
#    'id': 1013288048446980096,
#    'user_id': 3181196792,
#    'created_at': '2018-07-01 05:07:51',
#    'text': '❄️❄️❄️⛸⛸ https://t.co/n6o6tL874c',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1014868498470850564',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1014868498470850564',
#    '_rev': '1-5f0c981033570302a2a23ceb9f819aa6',
#    'id': 1014868498470850564,
#    'user_id': 3181196792,
#    'created_at': '2018-07-05 13:48:00',
#    'text': '😊 https://t.co/BASP8W1fFc',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1016678546482188289',
#   'key': 'Adelaide',
#   'value': 0.95856357,
#   'doc': {'_id': '1016678546482188289',
#    '_rev': '1-7441f44be9b37b6f928fe5f7702c0d63',
#    'id': 1016678546482188289,
#    'user_id': 3181196792,
#    'created_at': '2018-07-10 13:40:29',
#    'text': 'DR RICHARD “Harry” HARRIS #LocalLegend 😊 We Salute your Bravery and  Compassion 🙌🏻🙌🏻 You are an Adelaide Hero 🏆… https://t.co/yoJ8PxQj8Y',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.95856357',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1020962805808168961',
#   'key': 'Adelaide',
#   'value': 0.9853459,
#   'doc': {'_id': '1020962805808168961',
#    '_rev': '1-777e8c252f78fdabe3bbcedb8527016d',
#    'id': 1020962805808168961,
#    'user_id': 3181196792,
#    'created_at': '2018-07-22 09:24:36',
#    'text': '#WhereWonderMeetsWisdom \nThe Adelaide Set are partnering with this great South Australian Icon @nationalpharmcies a… https://t.co/E515mSy7hg',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9853459',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1021692656492077056',
#   'key': 'Adelaide',
#   'value': 0.69305575,
#   'doc': {'_id': '1021692656492077056',
#    '_rev': '1-13381e59fbcb01e59afe159c2dd0c007',
#    'id': 1021692656492077056,
#    'user_id': 3181196792,
#    'created_at': '2018-07-24 09:44:46',
#    'text': '💙GIVE AWAY💚\nWin a National Pharmacies $500 Voucher Proudly South Australian since 1911 @nationalpharmacies \nHead to… https://t.co/knClhpmrm2',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.69305575',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1022077711987007495',
#   'key': 'Adelaide',
#   'value': 0.7312176,
#   'doc': {'_id': '1022077711987007495',
#    '_rev': '1-86fa399ef407aa050ecc81ceec4d42ae',
#    'id': 1022077711987007495,
#    'user_id': 3181196792,
#    'created_at': '2018-07-25 11:14:50',
#    'text': 'IMPORTANT SOUTH AUSTRALIAN MESSAGE 🙌🏻 😊 This is also one of the main reasons we started our account and why we pred… https://t.co/8neZEB0D8B',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.7312176',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1022108169407934464',
#   'key': 'Adelaide',
#   'value': 0.98802894,
#   'doc': {'_id': '1022108169407934464',
#    '_rev': '1-bf267c00409d0dd1a078e598e0287908',
#    'id': 1022108169407934464,
#    'user_id': 3181196792,
#    'created_at': '2018-07-25 13:15:52',
#    'text': 'Congrats !!! @Accordionhans 🙌🏻🎉🕺🏻☔️ https://t.co/XJFSi7qlEm',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.98802894',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1027694273330925573',
#   'key': 'Adelaide',
#   'value': 0.44978058,
#   'doc': {'_id': '1027694273330925573',
#    '_rev': '1-fcf5e8da1c3cac6d26263b63b28a7ee3',
#    'id': 1027694273330925573,
#    'user_id': 3181196792,
#    'created_at': '2018-08-09 23:13:03',
#    'text': 'How can you not love this weather ? It’s Friday, so get ready for the week end 🌧 And more of this lovely rain ☔️🌈 p… https://t.co/An2jDeYm26',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.44978058',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1028419449681059841',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1028419449681059841',
#    '_rev': '1-4755bfd2af656fc12e09ea220fd07a87',
#    'id': 1028419449681059841,
#    'user_id': 3181196792,
#    'created_at': '2018-08-11 23:14:38',
#    'text': '😊💕 https://t.co/AThqvU3R50',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1030966705147834368',
#   'key': 'Adelaide',
#   'value': 0.9573573,
#   'doc': {'_id': '1030966705147834368',
#    '_rev': '1-48b85514af88ca909f28f6910674dfe6',
#    'id': 1030966705147834368,
#    'user_id': 3181196792,
#    'created_at': '2018-08-18 23:56:31',
#    'text': '“A perfect view - Onkaparinga river estuary, Southport, South Australia” \nPic &amp; caption by @ela.a.photos .… https://t.co/DmRHbGfSEW',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9573573',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1031317371271700480',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1031317371271700480',
#    '_rev': '1-a2f1c2e0e38e51eff6dbc4fc737c2f07',
#    'id': 1031317371271700480,
#    'user_id': 3181196792,
#    'created_at': '2018-08-19 23:09:56',
#    'text': '🙌🏻 https://t.co/05xvsaqLOs',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1033501759329644544',
#   'key': 'Adelaide',
#   'value': 0.9693763,
#   'doc': {'_id': '1033501759329644544',
#    '_rev': '1-83a11474f9f79ec572ad5086e138a6c1',
#    'id': 1033501759329644544,
#    'user_id': 935384617929936898,
#    'created_at': '2018-08-25 23:49:55',
#    'text': 'Nice way to end pre-season with a session at the @Adelaide_FC and begin the transition into cricket with this bunch… https://t.co/IlxVKhuLtY',
#    'place': {'type': 'poi',
#     'name': 'Adelaide Football Club',
#     'fullname': 'Adelaide Football Club',
#     'bounding_box': '[[[138.49642360451261, -34.879194940679255], [138.49642360451261, -34.879194940679255], [138.49642360451261, -34.879194940679255], [138.49642360451261, -34.879194940679255]]]'},
#    'sentiment_score': '0.9693763',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1039550419112943619',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1039550419112943619',
#    '_rev': '1-4b5593a27ccaba4d67970c5ec476cd2d',
#    'id': 1039550419112943619,
#    'user_id': 3181196792,
#    'created_at': '2018-09-11 16:25:08',
#    'text': '🙌🏻🙌🏻💕 https://t.co/jHRFZSfGLq',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1039674599158345728',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1039674599158345728',
#    '_rev': '1-d128307ab39d8a365a137837af43251b',
#    'id': 1039674599158345728,
#    'user_id': 3181196792,
#    'created_at': '2018-09-12 00:38:35',
#    'text': '😯 https://t.co/BeaOKqN01S',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1052921191831232512',
#   'key': 'Adelaide',
#   'value': 0.9351575,
#   'doc': {'_id': '1052921191831232512',
#    '_rev': '1-2980c6b351930d0bb71bf3962230d2c3',
#    'id': 1052921191831232512,
#    'user_id': 3181196792,
#    'created_at': '2018-10-18 13:55:49',
#    'text': 'Couture Culture #AFF18 Runway pics are now up on our FaceBook page   https://t.co/Yq4mpP5zGm https://t.co/s6aTse3Rba',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9351575',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1053201971602051072',
#   'key': 'Adelaide',
#   'value': 0.9538287,
#   'doc': {'_id': '1053201971602051072',
#    '_rev': '1-c17987b2e6c68ee78d9e09d749524313',
#    'id': 1053201971602051072,
#    'user_id': 3181196792,
#    'created_at': '2018-10-19 08:31:32',
#    'text': '🎀 SA Designer Showcase AFF 2018 presented by @spendlessshoes Full album now live on The Adelaide Set Facebook page!… https://t.co/DTGieyUBnl',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9538287',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1054551562557636608',
#   'key': 'Adelaide',
#   'value': 0.75533,
#   'doc': {'_id': '1054551562557636608',
#    '_rev': '1-e09eb4a07eff6197674fbe3238063471',
#    'id': 1054551562557636608,
#    'user_id': 3181196792,
#    'created_at': '2018-10-23 01:54:19',
#    'text': 'Thoughts ? https://t.co/n0cMrftBmL',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.75533',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1054964883844931584',
#   'key': 'Adelaide',
#   'value': 0.8529955,
#   'doc': {'_id': '1054964883844931584',
#    '_rev': '1-ead9eec234570118b39bd591def68614',
#    'id': 1054964883844931584,
#    'user_id': 3181196792,
#    'created_at': '2018-10-24 05:16:43',
#    'text': 'Only in Adelaide can you ride your horse to the local city pub 😊for a friendly pint or two with mates 🐴🐴🍻🇦🇺 pic via… https://t.co/fqPmwa2tCt',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.8529955',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1070505613996818433',
#   'key': 'Adelaide',
#   'value': 0.78948224,
#   'doc': {'_id': '1070505613996818433',
#    '_rev': '1-e260006d7cd0aed479e1b3a9e61b9af6',
#    'id': 1070505613996818433,
#    'user_id': 295048951,
#    'created_at': '2018-12-06 02:30:02',
#    'text': 'Declared and done. #hippocraticoath @ The University of Adelaide https://t.co/c0He9VQddc',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.78948224',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1072267211782455296',
#   'key': 'Adelaide',
#   'value': 0.8543794,
#   'doc': {'_id': '1072267211782455296',
#    '_rev': '1-132576f09f2803a5f24076a8748be955',
#    'id': 1072267211782455296,
#    'user_id': 295048951,
#    'created_at': '2018-12-10 23:09:59',
#    'text': 'Photos of me+legends #gradweek2018 @ Bonython Hall https://t.co/Rfc3TvJ1Jb',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.8543794',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1080602143696928768',
#   'key': 'Adelaide',
#   'value': 0.98763156,
#   'doc': {'_id': '1080602143696928768',
#    '_rev': '1-9f88d8af5289c2a204118a061989388f',
#    'id': 1080602143696928768,
#    'user_id': 3181196792,
#    'created_at': '2019-01-02 23:10:02',
#    'text': 'Blue skies 💦🌞🐚 Coffin Bay \n#TheAdelaideSet #SouthAustralia #Beautiful #Explore #LiveLife #JustDoIt #Youth #Joy… https://t.co/Rf8Jfg3sn0',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.98763156',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1083262479306842112',
#   'key': 'Adelaide',
#   'value': 0.9299072,
#   'doc': {'_id': '1083262479306842112',
#    '_rev': '1-0f45d2576a7b1bae39f11e205d801c2f',
#    'id': 1083262479306842112,
#    'user_id': 851758539248852992,
#    'created_at': '2019-01-10 07:21:15',
#    'text': '“The fruit from this orchard is for everyone to share and enjoy”. Community Fruit Garden, Fullarton. Nice work city… https://t.co/mgNnu3lv6o',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9299072',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1084321430307631105',
#   'key': 'Adelaide',
#   'value': 0.9709165,
#   'doc': {'_id': '1084321430307631105',
#    '_rev': '1-c1c9d33aa9e98448a60a61b61baa4e7f',
#    'id': 1084321430307631105,
#    'user_id': 20743221,
#    'created_at': '2019-01-13 05:29:09',
#    'text': 'Congrats @chloe_hosking  @CipolliniTeam winning the 4th and final stage women’s @tourdownunder #wtdu https://t.co/zVZBfo6GXk',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9709165',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1085036652098072576',
#   'key': 'Adelaide',
#   'value': 0.98295844,
#   'doc': {'_id': '1085036652098072576',
#    '_rev': '1-8310515bf3c8149681259c14b96fb4c9',
#    'id': 1085036652098072576,
#    'user_id': 20743221,
#    'created_at': '2019-01-15 04:51:11',
#    'text': 'Congrats @eliaviviani @deceuninck_qst on the stage 1 win! @tourdownunder #tdu https://t.co/eoRE9Xu1re',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.98295844',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1085412262494593030',
#   'key': 'Adelaide',
#   'value': 0.984639,
#   'doc': {'_id': '1085412262494593030',
#    '_rev': '1-ac14dab43840122e1274cc4c207126f6',
#    'id': 1085412262494593030,
#    'user_id': 20743221,
#    'created_at': '2019-01-16 05:43:44',
#    'text': 'Congrats @PaddyBevin on the stage 2 win! 💪🏽 @cccteam @tourdownunder #tdu https://t.co/Rie9ZBRjIn',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.984639',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1102506448913760256',
#   'key': 'Adelaide',
#   'value': 0.29888737,
#   'doc': {'_id': '1102506448913760256',
#    '_rev': '1-3729677f35561a398c90e9643fa9e3a4',
#    'id': 1102506448913760256,
#    'user_id': 705207858539814912,
#    'created_at': '2019-03-04 09:49:55',
#    'text': 'I’m just a viewer of @ABCTV, and half his age (and a bit), but gees Mike Willesee is a loss. A loss, yes, but not a… https://t.co/R7t0cvX8af',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.29888737',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1103782976704466944',
#   'key': 'Adelaide',
#   'value': 0.8482095,
#   'doc': {'_id': '1103782976704466944',
#    '_rev': '1-3658905ef4747aff22f6a5401c11170d',
#    'id': 1103782976704466944,
#    'user_id': 851758539248852992,
#    'created_at': '2019-03-07 22:22:23',
#    'text': 'Adelaide’s best bus stop?\n. . .\n#adelaide #busstop #publictransport #urbandesign #landscape @ Beaumont, South Austr… https://t.co/i70uCle0sQ',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.8482095',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1110152828830408706',
#   'key': 'Adelaide',
#   'value': 0.67003083,
#   'doc': {'_id': '1110152828830408706',
#    '_rev': '1-289d0ae58a4f43f39f513903c143e424',
#    'id': 1110152828830408706,
#    'user_id': 434069593,
#    'created_at': '2019-03-25 12:13:54',
#    'text': 'https://t.co/V8pzMLFYQj',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67003083',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1124844829467394048',
#   'key': 'Adelaide',
#   'value': 0.0837985,
#   'doc': {'_id': '1124844829467394048',
#    '_rev': '1-20d5ed623d5d1d54e3290f9bbc8e168a',
#    'id': 1124844829467394048,
#    'user_id': 295048951,
#    'created_at': '2019-05-05 01:14:40',
#    'text': 'Blood sweat and a lot of tears #realmencry @ The University of Adelaide https://t.co/Xxxx7vFT52',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.0837985',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1132964643620630529',
#   'key': 'Adelaide',
#   'value': 0.82601845,
#   'doc': {'_id': '1132964643620630529',
#    '_rev': '1-67298fd1fa9d41bc2ec95b6b7595a3bf',
#    'id': 1132964643620630529,
#    'user_id': 434069593,
#    'created_at': '2019-05-27 10:59:55',
#    'text': 'ACW REDEMPTION, June 29th, I take what is rightfully mine, I will beat Ritchie Taylor and become the number 1 conte… https://t.co/gydIohZDRN',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.82601845',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1134352156570443777',
#   'key': 'Adelaide',
#   'value': 0.84717995,
#   'doc': {'_id': '1134352156570443777',
#    '_rev': '1-67c871e23d717227ea6cac5cde391fdb',
#    'id': 1134352156570443777,
#    'user_id': 705207858539814912,
#    'created_at': '2019-05-31 06:53:24',
#    'text': 'So seriously cool. This awesomeness should not just be contained to Australia. https://t.co/s9EacINi31',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.84717995',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1135713329509355521',
#   'key': 'Adelaide',
#   'value': 0.39631936,
#   'doc': {'_id': '1135713329509355521',
#    '_rev': '1-21dfcca9153c4451a248f6cdbb90aeda',
#    'id': 1135713329509355521,
#    'user_id': 434069593,
#    'created_at': '2019-06-04 01:02:12',
#    'text': '30/05/17 is the day that The Luch passed away two years ago, this Saturday PWSA stars compete in a battle royal in… https://t.co/VioGTQzkoV',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.39631936',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1138194187705245697',
#   'key': 'Adelaide',
#   'value': 0.5702672,
#   'doc': {'_id': '1138194187705245697',
#    '_rev': '1-2f2c970e374b5aca9a19a8d10a15ce83',
#    'id': 1138194187705245697,
#    'user_id': 935384617929936898,
#    'created_at': '2019-06-10 21:20:15',
#    'text': 'Not long now! The @wcsmc2019 is shaping up to be a good one.  #research #conference https://t.co/I5EMwaBOJy',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.5702672',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1138712006616408065',
#   'key': 'Adelaide',
#   'value': 0.99290395,
#   'doc': {'_id': '1138712006616408065',
#    '_rev': '1-2e5c5ffeb1d6b2314ddda29d6973a829',
#    'id': 1138712006616408065,
#    'user_id': 2998887637,
#    'created_at': '2019-06-12 07:37:53',
#    'text': 'Shop online , \nenjoy free post 📦✨ \nand welcome this antique masterpiece to your home  🏠 💫… https://t.co/pfjDLG5LB5',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.99290395',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1138773911678607367',
#   'key': 'Adelaide',
#   'value': 0.06049338,
#   'doc': {'_id': '1138773911678607367',
#    '_rev': '1-749b80bf56d65e5af4f1359abb872823',
#    'id': 1138773911678607367,
#    'user_id': 705207858539814912,
#    'created_at': '2019-06-12 11:43:52',
#    'text': 'Is there an #ubereats twitter account for Australia? Can only find U.K., France, USA, India etc but no Oz. Certainl… https://t.co/D4yuucBrlq',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.06049338',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1139046190941712384',
#   'key': 'Adelaide',
#   'value': 0.9949649,
#   'doc': {'_id': '1139046190941712384',
#    '_rev': '1-6635bbb75df60e1d205042f1039c7537',
#    'id': 1139046190941712384,
#    'user_id': 2998887637,
#    'created_at': '2019-06-13 05:45:49',
#    'text': 'Happy Thursday ✨                Check the range of our beautiful cushions for tour sweet home 🏠… https://t.co/Hh9hCuGiMN',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9949649',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1139687359765606400',
#   'key': 'Adelaide',
#   'value': 0.9523215,
#   'doc': {'_id': '1139687359765606400',
#    '_rev': '1-b96a9b8a9966e871e5bdcf57fdddb21e',
#    'id': 1139687359765606400,
#    'user_id': 2998887637,
#    'created_at': '2019-06-15 00:13:35',
#    'text': 'Happy Saturday ✨🎉             Weekend is here👌🍷             For your convenience shop centralmarketarcade is open 9… https://t.co/9ZmbFfDHnl',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9523215',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1139857055940935680',
#   'key': 'Adelaide',
#   'value': 0.030938953,
#   'doc': {'_id': '1139857055940935680',
#    '_rev': '1-1fafe425d199ebe1ec2477b641bac0af',
#    'id': 1139857055940935680,
#    'user_id': 705207858539814912,
#    'created_at': '2019-06-15 11:27:54',
#    'text': 'Anyone had a bad experience with #ubereats? Driver? Customer service?',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.030938953',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1140391869123198976',
#   'key': 'Adelaide',
#   'value': 0.5110419,
#   'doc': {'_id': '1140391869123198976',
#    '_rev': '1-b524cbcf9823aec23954f46566f35d72',
#    'id': 1140391869123198976,
#    'user_id': 705207858539814912,
#    'created_at': '2019-06-16 22:53:03',
#    'text': 'Even in South Africa, @UberEats ? How validating of my abysmal experience of #ubereats in Australia. https://t.co/GGehEDvkDS',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.5110419',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1140392076254650368',
#   'key': 'Adelaide',
#   'value': 0.95870435,
#   'doc': {'_id': '1140392076254650368',
#    '_rev': '1-b653a57cb506feabf976d9058bd90199',
#    'id': 1140392076254650368,
#    'user_id': 705207858539814912,
#    'created_at': '2019-06-16 22:53:53',
#    'text': 'SURPRISE! https://t.co/BEhP3XVelr',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.95870435',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1140392660034674688',
#   'key': 'Adelaide',
#   'value': 0.20839384,
#   'doc': {'_id': '1140392660034674688',
#    '_rev': '1-385b0a4dcca563f9077bad18a5116d0a',
#    'id': 1140392660034674688,
#    'user_id': 705207858539814912,
#    'created_at': '2019-06-16 22:56:12',
#    'text': 'Yeap, @UberEats. My issue is not ‘resolved’ and inviting me to go to the police in your response is truly an expres… https://t.co/q6etnIsVFx',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.20839384',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1140393267659300864',
#   'key': 'Adelaide',
#   'value': 0.089163125,
#   'doc': {'_id': '1140393267659300864',
#    '_rev': '1-a1276e56333ace18c242278fa6853388',
#    'id': 1140393267659300864,
#    'user_id': 705207858539814912,
#    'created_at': '2019-06-16 22:58:37',
#    'text': '#Ubereats @UberEats SO UNPROFESSIONAL. Nightmare experience and then just effectively told to go away. Never using… https://t.co/cOIVrzmhP5',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.089163125',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1140856224935763968',
#   'key': 'Adelaide',
#   'value': 0.97864795,
#   'doc': {'_id': '1140856224935763968',
#    '_rev': '1-1494cd002a0611c176604bd9babfc4e9',
#    'id': 1140856224935763968,
#    'user_id': 2998887637,
#    'created_at': '2019-06-18 05:38:14',
#    'text': '✨Shop online, enter code “my10%” enjoy free post plus extra 10% discount here👇\n\nhttps://t.co/Sh0X9z24jO\n\n#adelaide… https://t.co/Mtlh7pdjkF',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.97864795',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1141174638057316358',
#   'key': 'Adelaide',
#   'value': 0.52196217,
#   'doc': {'_id': '1141174638057316358',
#    '_rev': '1-4e42cf6840887357c1958136cc323083',
#    'id': 1141174638057316358,
#    'user_id': 2998887637,
#    'created_at': '2019-06-19 02:43:30',
#    'text': 'Wishing everyone a very warm Wednesday 🤔 !                              🥶 it’s cold in Adelaide but you can warm up… https://t.co/h9ecpkKqzc',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.52196217',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1141221990566641664',
#   'key': 'Adelaide',
#   'value': 0.52196217,
#   'doc': {'_id': '1141221990566641664',
#    '_rev': '1-b54dfe083069e87e9721addbcac79b0a',
#    'id': 1141221990566641664,
#    'user_id': 2998887637,
#    'created_at': '2019-06-19 05:51:40',
#    'text': 'Wishing everyone a very warm Wednesday 🤔 !                              🥶 it’s cold in Adelaide but you can warm up… https://t.co/OsyVLD9Bfs',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.52196217',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1141937513860345856',
#   'key': 'Adelaide',
#   'value': 0.966822,
#   'doc': {'_id': '1141937513860345856',
#    '_rev': '1-b5ed513b50ea154090d7fb219dffef24',
#    'id': 1141937513860345856,
#    'user_id': 2998887637,
#    'created_at': '2019-06-21 05:14:54',
#    'text': 'Finally Friday 👌                               ❄️☁️❄️⛈❄️                                         Shop in Central Ma… https://t.co/dMtkKoQCFX',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.966822',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1142018391089328128',
#   'key': 'Adelaide',
#   'value': 0.98441887,
#   'doc': {'_id': '1142018391089328128',
#    '_rev': '1-cf5f78d6cc4d97cb5fe2e40b15a59b22',
#    'id': 1142018391089328128,
#    'user_id': 2998887637,
#    'created_at': '2019-06-21 10:36:16',
#    'text': 'Finally Friday 👌                                         ❄️☁️❄️⛈❄️                                         Shop in… https://t.co/t0uYF52ggF',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.98441887',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1142996839526014977',
#   'key': 'Adelaide',
#   'value': 0.049457222,
#   'doc': {'_id': '1142996839526014977',
#    '_rev': '1-25fab2c05d4935af5785835edb6ed997',
#    'id': 1142996839526014977,
#    'user_id': 2998887637,
#    'created_at': '2019-06-24 03:24:17',
#    'text': '❄️☁️❄️⛈❄️                                         ❄️🥶❄️🥶❄️                           It’s Cold 🥶… https://t.co/ZvFxtZZt5U',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.049457222',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1145594232813625345',
#   'key': 'Adelaide',
#   'value': 0.97534454,
#   'doc': {'_id': '1145594232813625345',
#    '_rev': '1-d37d620be597fc995acdf28f0e99b970',
#    'id': 1145594232813625345,
#    'user_id': 2998887637,
#    'created_at': '2019-07-01 07:25:23',
#    'text': 'Happy Monday 😊\nMonday is back and another beautiful week is here                                          ✨… https://t.co/gY5HJmPIv5',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.97534454',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1147059456703729665',
#   'key': 'Adelaide',
#   'value': 0.6180136,
#   'doc': {'_id': '1147059456703729665',
#    '_rev': '1-4c6d2c2dcef9d83cdd480c96f8579f79',
#    'id': 1147059456703729665,
#    'user_id': 434069593,
#    'created_at': '2019-07-05 08:27:40',
#    'text': 'Came up short, but @RitchieTaylor6  is the real deal Australia, enjoyed battling him at @ACWrestlingSA Redemption! https://t.co/B9pvpf4iKI',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.6180136',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1148692475050991616',
#   'key': 'Adelaide',
#   'value': 0.97957635,
#   'doc': {'_id': '1148692475050991616',
#    '_rev': '1-9e6f557b0ade7632fddbfe9abc65ff14',
#    'id': 1148692475050991616,
#    'user_id': 705207858539814912,
#    'created_at': '2019-07-09 20:36:42',
#    'text': 'Wow. Pub Choir is one of the greatest things to come out of Oz. Ever. https://t.co/pVDbtHOhoM',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.97957635',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1148800141006032896',
#   'key': 'Adelaide',
#   'value': 0.57629424,
#   'doc': {'_id': '1148800141006032896',
#    '_rev': '1-8348c4b56cbef936ca353f2ba7437c15',
#    'id': 1148800141006032896,
#    'user_id': 2998887637,
#    'created_at': '2019-07-10 03:44:31',
#    'text': 'Happy Wednesday 😊\nI know I’ve been missed😉 Here I am back with lots of great offer just for you… https://t.co/nYECIfnP88',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.57629424',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1149500931022569474',
#   'key': 'Adelaide',
#   'value': 0.9854826,
#   'doc': {'_id': '1149500931022569474',
#    '_rev': '1-b2cd3e53348a1cb20142b7a18b89f749',
#    'id': 1149500931022569474,
#    'user_id': 2998887637,
#    'created_at': '2019-07-12 02:09:13',
#    'text': 'Finally Friday 👌                                         ☁️                  ⛈… https://t.co/Sey97IttrP',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9854826',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1149882812679561216',
#   'key': 'Adelaide',
#   'value': 0.9847055,
#   'doc': {'_id': '1149882812679561216',
#    '_rev': '1-90a38a588bf0b97baef794124bd8c2c1',
#    'id': 1149882812679561216,
#    'user_id': 2998887637,
#    'created_at': '2019-07-13 03:26:40',
#    'text': 'Happy Saturday ✨🎉               Weekend is here👌🍷             \nFor your convenience shop at Central Market Arcade i… https://t.co/oKyILKxzrv',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9847055',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1154967699728084993',
#   'key': 'Adelaide',
#   'value': 0.74749523,
#   'doc': {'_id': '1154967699728084993',
#    '_rev': '1-cd9b26e91baa6e8eb45d8a9714bf2f18',
#    'id': 1154967699728084993,
#    'user_id': 2998887637,
#    'created_at': '2019-07-27 04:12:12',
#    'text': 'Wishing everyone a very happyand relaxing 😎 weekend 🌞                                                      Shop in… https://t.co/fqKvmfGKgI',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.74749523',
# ...
#   'value': 0.9883356,
#   'doc': {'_id': '1174956141626871808',
#    '_rev': '1-b1cbe26af1cc070e03e8ee929cdb802f',
#    'id': 1174956141626871808,
#    'user_id': 2998887637,
#    'created_at': '2019-09-20 07:59:08',
#    'text': 'Wishing everyone a very happy and relaxing 😎 weekend 🌞                                                      \n\nShop… https://t.co/hfic1uCJAz',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9883356',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1176245427257016320',
#   'key': 'Adelaide',
#   'value': 0.95751846,
#   'doc': {'_id': '1176245427257016320',
#    '_rev': '1-9671b9ab8f21240c011c83a973ca5bdf',
#    'id': 1176245427257016320,
#    'user_id': 935384617929936898,
#    'created_at': '2019-09-23 21:22:18',
#    'text': 'NEW PAPER: External and internal workload demands of women’s twenty 20 cricket competition\n\nThanks to @uniSA… https://t.co/b9qVBRoEIj',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.95751846',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1177490013338005509',
#   'key': 'Adelaide',
#   'value': 0.8978917,
#   'doc': {'_id': '1177490013338005509',
#    '_rev': '1-fe7c0f0fc54c80eb55c0e6c6b9f0a386',
#    'id': 1177490013338005509,
#    'user_id': 2998887637,
#    'created_at': '2019-09-27 07:47:50',
#    'text': 'Wishing everyone a very happy school 🏫 Holidays 🌞                                         🤩Shop in Central Market o… https://t.co/uxStZ1A8b6',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.8978917',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182591083672473600',
#   'key': 'Adelaide',
#   'value': 0.67493165,
#   'doc': {'_id': '1182591083672473600',
#    '_rev': '1-c2e19a514bd06c29837122ca89554baf',
#    'id': 1182591083672473600,
#    'user_id': 3074620333,
#    'created_at': '2019-10-11 09:37:40',
#    'text': 'Bathroom Renovation.\n\n#edmondsmaintenance #bathroomdesign #bathroomsofinstagram #bathroomstyling #bathroomideas… https://t.co/pzhTLnAywS',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.67493165',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182596080367755264',
#   'key': 'Adelaide',
#   'value': 0.88677824,
#   'doc': {'_id': '1182596080367755264',
#    '_rev': '1-6437755b194babcc6d1928a0a865e5a8',
#    'id': 1182596080367755264,
#    'user_id': 3074620333,
#    'created_at': '2019-10-11 09:57:31',
#    'text': "Every bathroom has it's own unique look.\n\nThis one can be made a pool now with double layer of waterproofing before… https://t.co/u7cHTXEeNg",
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.88677824',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182597878201667584',
#   'key': 'Adelaide',
#   'value': 0.6265472,
#   'doc': {'_id': '1182597878201667584',
#    '_rev': '1-1890ce70ef52a0977f7f56a66d9abf45',
#    'id': 1182597878201667584,
#    'user_id': 3074620333,
#    'created_at': '2019-10-11 10:04:40',
#    'text': '1/2\n\n#edmondsmaintenance #tilingideas #tilework #wallandfloortiling #adelaide #southaustralia #sabrand… https://t.co/G8Y5FFQBtf',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.6265472',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182773759436099584',
#   'key': 'Adelaide',
#   'value': 0.40409204,
#   'doc': {'_id': '1182773759436099584',
#    '_rev': '1-6534999deb984d0a959f783b9877b4a9',
#    'id': 1182773759436099584,
#    'user_id': 3074620333,
#    'created_at': '2019-10-11 21:43:33',
#    'text': 'House Rental Preparation.\n\nCrack treatments, celling,walls,windows and doors painted.\nReplaced all doors, replaced… https://t.co/ZPPJkuUNss',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.40409204',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182832780331405317',
#   'key': 'Adelaide',
#   'value': 0.9132103,
#   'doc': {'_id': '1182832780331405317',
#    '_rev': '1-b12bf93cea050aa70efdeb4193a35fc0',
#    'id': 1182832780331405317,
#    'user_id': 3074620333,
#    'created_at': '2019-10-12 01:38:05',
#    'text': 'Tell us you dream we make it reality.\n\n#edmondsmaintenance #wallandfloortiling #tilework #tiling #tilingideas… https://t.co/k6tP57gX8f',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9132103',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182834649288060928',
#   'key': 'Adelaide',
#   'value': 0.63246846,
#   'doc': {'_id': '1182834649288060928',
#    '_rev': '1-6d4ecd916434a0851b158388af3aa262',
#    'id': 1182834649288060928,
#    'user_id': 3074620333,
#    'created_at': '2019-10-12 01:45:31',
#    'text': 'No job is to big, no job is to small.\nWe just love what we do especially when is outside on nice day like this 🤗… https://t.co/c13TYgsFKc',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.63246846',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1182961955755061249',
#   'key': 'Adelaide',
#   'value': 0.9776789,
#   'doc': {'_id': '1182961955755061249',
#    '_rev': '1-699d6bdec719bd7540d95a1659f604be',
#    'id': 1182961955755061249,
#    'user_id': 935384617929936898,
#    'created_at': '2019-10-12 10:11:23',
#    'text': 'Amazing 🏃\u200d♂️ https://t.co/hccnGon3Np',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9776789',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1183537361898135558',
#   'key': 'Adelaide',
#   'value': 0.9728588,
#   'doc': {'_id': '1183537361898135558',
#    '_rev': '1-a3c880c025c1d35402dc5301f269fc7a',
#    'id': 1183537361898135558,
#    'user_id': 2998887637,
#    'created_at': '2019-10-14 00:17:50',
#    'text': 'Happy Monday 😊                         with School Holidays finished yesterday now everyone including little ones b… https://t.co/iFGMms8oGQ',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9728588',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1183977558565539840',
#   'key': 'Adelaide',
#   'value': 0.99614114,
#   'doc': {'_id': '1183977558565539840',
#    '_rev': '1-f75a4c97c521245ac5421f081dcdc8bd',
#    'id': 1183977558565539840,
#    'user_id': 391912091,
#    'created_at': '2019-10-15 05:27:01',
#    'text': 'Thank you🙌🏽💯 https://t.co/rs8pcaGrAH',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.99614114',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1185018964524421122',
#   'key': 'Adelaide',
#   'value': 0.99109226,
#   'doc': {'_id': '1185018964524421122',
#    '_rev': '1-5edc7d02836ef7aefb4c9ee467478d47',
#    'id': 1185018964524421122,
#    'user_id': 2998887637,
#    'created_at': '2019-10-18 02:25:12',
#    'text': '😲😮😲😮😲😮😲😮😲😮 USE COUPON CODE:                         🛍           “SPRING”                                     ENJOY… https://t.co/0lHvd0XSSR',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.99109226',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1185348668854960128',
#   'key': 'Adelaide',
#   'value': 0.90173364,
#   'doc': {'_id': '1185348668854960128',
#    '_rev': '1-ea92b87e63ce5fdd612d3d175109bd82',
#    'id': 1185348668854960128,
#    'user_id': 2998887637,
#    'created_at': '2019-10-19 00:15:20',
#    'text': '😲😮😲😮😲😮😲😮😲😮 \nUSE COUPON CODE:                         \n🛍                “SPRING”… https://t.co/EHgcTutDtV',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.90173364',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1187579507961663489',
#   'key': 'Adelaide',
#   'value': 0.9796514,
#   'doc': {'_id': '1187579507961663489',
#    '_rev': '1-0bd1e948a6d7b19800cc70be4e43081e',
#    'id': 1187579507961663489,
#    'user_id': 2998887637,
#    'created_at': '2019-10-25 03:59:53',
#    'text': 'Wishing everyone a very happy and relaxing weekend 😎                                                      \n\nShop in… https://t.co/qb6GUC2gp9',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9796514',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1192626468695658496',
#   'key': 'Adelaide',
#   'value': 0.87435305,
#   'doc': {'_id': '1192626468695658496',
#    '_rev': '1-c8e00128083addd810b097badec8b7d8',
#    'id': 1192626468695658496,
#    'user_id': 2998887637,
#    'created_at': '2019-11-08 02:14:42',
#    'text': 'Can’t wait to welcome you  @patpersia centralmarketarcade today 😊 \n\nshop at Central Market Arcade is open till 9:00… https://t.co/0aJiNs7dbn',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.87435305',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1193018810636201984',
#   'key': 'Adelaide',
#   'value': 0.9627875,
#   'doc': {'_id': '1193018810636201984',
#    '_rev': '1-dbf32a7f17ff234939aa15b578bd5ce9',
#    'id': 1193018810636201984,
#    'user_id': 9611682,
#    'created_at': '2019-11-09 04:13:44',
#    'text': 'Your passion and purpose to help people with health, wellness and wellbeing really shines through https://t.co/lTib03IaBO',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.9627875',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1194742989915971584',
#   'key': 'Adelaide',
#   'value': 0.05311811,
#   'doc': {'_id': '1194742989915971584',
#    '_rev': '1-243ccea9d9a21370190f95a807d650ff',
#    'id': 1194742989915971584,
#    'user_id': 434069593,
#    'created_at': '2019-11-13 22:25:00',
#    'text': 'Rip legend https://t.co/BH9CpBJfg3',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.05311811',
#    'sentiment': 'Negative',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1196694316137058304',
#   'key': 'Adelaide',
#   'value': 0.5494305,
#   'doc': {'_id': '1196694316137058304',
#    '_rev': '1-e44052a3e12863857bdfd1f051c860fd',
#    'id': 1196694316137058304,
#    'user_id': 9611682,
#    'created_at': '2019-11-19 07:38:53',
#    'text': 'Regional entrepreneurs are key contributors to the economic and jobs growth of our regions https://t.co/JdqCKhKbKf',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.5494305',
#    'sentiment': 'Neutral',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1196904314649767936',
#   'key': 'Adelaide',
#   'value': 0.95623934,
#   'doc': {'_id': '1196904314649767936',
#    '_rev': '1-d84ef9d339f4d872529b826fa2022ed1',
#    'id': 1196904314649767936,
#    'user_id': 9611682,
#    'created_at': '2019-11-19 21:33:20',
#    'text': 'Best wishes from the team  @NVIFlinders - we are proud to be supporting @gomicro through  the #Flinders… https://t.co/Fk1l8BCy2M',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.95623934',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}},
#  {'id': '1196976058379198465',
#   'key': 'Adelaide',
#   'value': 0.93485415,
#   'doc': {'_id': '1196976058379198465',
#    '_rev': '1-c3d2d08372b5da460c44e234103e9f37',
#    'id': 1196976058379198465,
#    'user_id': 459781084,
#    'created_at': '2019-11-20 02:18:25',
#    'text': 'Hosted by the The Media Resource Centre in Adelaide, I viewed with unwavering enthusiasm, my 5th screening of… https://t.co/S2a7jHDxOZ',
#    'place': {'type': 'city',
#     'name': 'Adelaide',
#     'fullname': 'Adelaide, South Australia',
#     'bounding_box': '[[[138.44212992, -35.348970061], [138.780189824, -35.348970061], [138.780189824, -34.652564053], [138.44212992, -34.652564053]]]'},
#    'sentiment_score': '0.93485415',
#    'sentiment': 'Positive',
#    'zone': 'Adelaide',
#    'keywords': 'no keywords'}}]
